# %% [markdown]
# # Model Training Research: Candidate Models and Considerations
#
# This document outlines candidate models to be considered for our wine quality prediction task, along with key factors to evaluate during the research phase.
#
# ## Candidate Models
#
# Here are some potential machine learning models that could be explored for predicting wine quality:
#
# 1. **Decision Trees:**
#    - **Strengths:** Flexible and can handle both continuous and categorical features without extensive data preprocessing. Robust to outliers.
#    - **Weaknesses:** Prone to overfitting if not properly tuned. Can be less interpretable than linear models.
#
# 2. **Random Forests:**
#    - **Strengths:** Ensemble method combining multiple decision trees, leading to improved accuracy and reduced overfitting compared to single decision trees.
#    - **Weaknesses:** Interpretability can be challenging due to the ensemble nature. May require hyperparameter tuning for optimal performance.
#
# 3. **Support Vector Machines (SVMs):**
#    - **Strengths:** Powerful for classification tasks, especially with high-dimensional data. Effective at handling non-linear relationships using kernel functions.
#    - **Weaknesses:** Sensitive to outliers and feature scaling. Can be computationally expensive for large datasets.
#
# 4. **K-Nearest Neighbors (KNN):**
#    - **Strengths:** Simple and easy to implement. No explicit model training required. Effective for both classification and regression.
#    - **Weaknesses:** Performance can be affected by the "curse of dimensionality." Sensitive to noisy data and choice of distance metric.
#
# 5. **Logistic Regression:**
#    - **Strengths:** Simple and interpretable. Suitable for binary classification tasks. Can handle large datasets efficiently.
#    - **Weaknesses:** Assumes linear relationship between features and target variable. May underperform if the data is not linearly separable.
#
# 6. **Gradient Boosting Machines (GBM):**
#    - **Strengths:** Builds decision trees sequentially, focusing on correcting errors made by previous trees. Typically achieves high accuracy.
#    - **Weaknesses:** Prone to overfitting if not properly regularized. Requires careful tuning of hyperparameters.
#
# 7. **Naive Bayes:**
#    - **Strengths:** Simple and fast to train. Performs well on text classification tasks and with categorical features.
#    - **Weaknesses:** Assumes independence between features, which may not hold true in practice. Can be sensitive to imbalanced class distributions.
#
# 8. **Neural Networks:**
#    - **Strengths:** Capable of learning complex patterns in data. Can handle high-dimensional inputs and non-linear relationships.
#    - **Weaknesses:** Requires large amounts of data for training. May suffer from overfitting if not properly regularized. Computationally intensive.
#
# ## Selection Criteria
#
# When evaluating these models, we should consider the following factors:
#
# - **Problem Type:** Since we're predicting wine quality (likely a categorical variable), we'll be focusing on classification models.
# - **Data Characteristics:**
#   - Feature types (continuous, categorical)
#   - Data size and dimensionality
#   - Presence of missing values or outliers
# - **Model Performance:**
#   - Accuracy, precision, recall, F1-score (depending on class imbalance)
#   - Overfitting potential
# - **Interpretability:**
#   - Importance of understanding model predictions and feature relationships
#   - Trade-off between accuracy and interpretability
#
# ## Research Plan
#
# The research will involve:
#
# 1. **Data Preprocessing:** Exploring data cleaning, handling missing values, and feature scaling if necessary.
# 2. **Model Training and Evaluation:** Implementing and training each candidate model with appropriate hyperparameter tuning. Evaluating performance metrics on a separate validation set.
# 3. **Model Selection:** Choosing the model with the best balance of accuracy, interpretability, and suitability for the data.
# 4. **Model Interpretation:** Analyzing the chosen model to understand how features influence predictions (if applicable).
#
# Through this research, we aim to identify the most effective model for predicting wine quality based on the given dataset and evaluation criteria.
# ed on the given dataset and evaluation criteria.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier
from catboost import CatBoostClassifier
from xgboost import XGBClassifier

# %%
df = pd.read_csv("new_df_wine.csv")
df.head()
# Out:
#    Unnamed: 0  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0           0            7.4              0.70         0.00             1.9
# 1           1            7.8              0.88         0.00             2.6
# 2           2            7.8              0.76         0.04             2.3
# 3           3           11.2              0.28         0.56             1.9
# 4           5            7.4              0.66         0.00             1.8
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.076                 11.0                  34.0   0.9978  3.51
# 1      0.098                 25.0                  67.0   0.9968  3.20
# 2      0.092                 15.0                  54.0   0.9970  3.26
# 3      0.075                 17.0                  60.0   0.9980  3.16
# 4      0.075                 13.0                  40.0   0.9978  3.51
#
#    sulphates  alcohol quality
# 0       0.56      9.4  medium
# 1       0.68      9.8  medium
# 2       0.65      9.8  medium
# 3       0.58      9.8  medium
# 4       0.56      9.4  medium

# %% [markdown]
# I will encode my target variable since some of the models can handle categorical data...

# %%
label_mapping = {'low': 0, 'medium': 1, 'high': 2}
# Map the labels to numerical values
df['quality'] = df['quality'].map(label_mapping)
df.head(20)
# Out:
#     Unnamed: 0  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0            0            7.4             0.700         0.00             1.9
# 1            1            7.8             0.880         0.00             2.6
# 2            2            7.8             0.760         0.04             2.3
# 3            3           11.2             0.280         0.56             1.9
# 4            5            7.4             0.660         0.00             1.8
# 5            6            7.9             0.600         0.06             1.6
# 6            7            7.3             0.650         0.00             1.2
# 7            8            7.8             0.580         0.02             2.0
# 8            9            7.5             0.500         0.36             6.1
# 9           10            6.7             0.580         0.08             1.8
# 10          12            5.6             0.615         0.00             1.6
# 11          13            7.8             0.610         0.29             1.6
# 12          14            8.9             0.620         0.18             3.8
# 13          15            8.9             0.620         0.19             3.9
# 14          16            8.5             0.280         0.56             1.8
# 15          17            8.1             0.560         0.28             1.7
# 16          18            7.4             0.590         0.08             4.4
# 17          19            7.9             0.320         0.51             1.8
# 18          20            8.9             0.220         0.48             1.8
# 19          21            7.6             0.390         0.31             2.3
#
#     chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0       0.076                 11.0                  34.0   0.9978  3.51
# 1       0.098                 25.0                  67.0   0.9968  3.20
# 2       0.092                 15.0                  54.0   0.9970  3.26
# 3       0.075                 17.0                  60.0   0.9980  3.16
# 4       0.075                 13.0                  40.0   0.9978  3.51
# 5       0.069                 15.0                  59.0   0.9964  3.30
# 6       0.065                 15.0                  21.0   0.9946  3.39
# 7       0.073                  9.0                  18.0   0.9968  3.36
# 8       0.071                 17.0                 102.0   0.9978  3.35
# 9       0.097                 15.0                  65.0   0.9959  3.28
# 10      0.089                 16.0                  59.0   0.9943  3.58
# 11      0.114                  9.0                  29.0   0.9974  3.26
# 12      0.176                 52.0                 145.0   0.9986  3.16
# 13      0.170                 51.0                 148.0   0.9986  3.17
# 14      0.092                 35.0                 103.0   0.9969  3.30
# 15      0.368                 16.0                  56.0   0.9968  3.11
# 16      0.086                  6.0                  29.0   0.9974  3.38
# 17      0.341                 17.0                  56.0   0.9969  3.04
# 18      0.077                 29.0                  60.0   0.9968  3.39
# 19      0.082                 23.0                  71.0   0.9982  3.52
#
#     sulphates  alcohol  quality
# 0        0.56      9.4        1
# 1        0.68      9.8        1
# 2        0.65      9.8        1
# 3        0.58      9.8        1
# 4        0.56      9.4        1
# 5        0.46      9.4        1
# 6        0.47     10.0        2
# 7        0.57      9.5        2
# 8        0.80     10.5        1
# 9        0.54      9.2        1
# 10       0.52      9.9        1
# 11       1.56      9.1        1
# 12       0.88      9.2        1
# 13       0.93      9.2        1
# 14       0.75     10.5        2
# 15       1.28      9.3        1
# 16       0.50      9.0        0
# 17       1.08      9.2        1
# 18       0.53      9.4        1
# 19       0.65      9.7        1

# %% [markdown]
# #### Train test split
# Doing this now to avoid data leakage.

# %%
def train_test(df,target_column,test_size,random_state):
    """
    Perform train-test split on a DataFrame.
    
    Parameters:
    df (DataFrame): The DataFrame containing features and target variable.
    target_variable (str): The name of the target variable.
    random_state (int): Random state for reproducibility.
    test_size (float): The proportion of the dataset to include in the test split.
    
    Returns:
    X_train (DataFrame): The features for training.
    X_test (DataFrame): The features for testing.
    y_train (Series): The target variable for training.
    y_test (Series): The target variable for testing.
    """
    X = df.drop(target_column,axis = 1)
    X = df.drop('Unnamed: 0',axis = 1)
    y = df[target_column]

    X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=test_size,random_state=random_state)
    return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = train_test(df,'quality',0.2,42)

# %%
X_train.shape, y_test.shape
# Out:
# ((1087, 12), (272,))

# %%
from sklearn.compose import ColumnTransformer
num_features = X_train.select_dtypes(exclude="object").columns
numeric_transformer = StandardScaler()

# %%
preprocessor = ColumnTransformer(
    [
         ("StandardScaler", numeric_transformer, num_features)       
    ]
)

# %%
X_train = preprocessor.fit_transform(X_train)
X_test = preprocessor.transform(X_test)

X_train.shape,X_test.shape
# Out:
# ((1087, 12), (272, 12))

# %%
X_train
# Out:
# array([[ 0.35162311, -0.82832312,  0.64877105, ...,  0.51985077,
#          1.98424001,  2.17644617],
#        [-0.98154785,  0.96589124, -0.98983279, ..., -0.45848943,
#         -0.2158671 , -0.22537818],
#        [-0.86561994,  0.18092246, -1.24586464, ..., -0.17074231,
#         -0.39920936, -0.22537818],
#        ...,
#        [-0.86561994, -0.32370033, -0.98983279, ..., -0.05564346,
#         -0.76589387, -0.22537818],
#        [ 0.35162311, -1.16473831,  0.18791372, ..., -0.6311377 ,
#         -0.03252484, -0.22537818],
#        [ 0.46755102, -1.05259991,  0.75118379, ..., -0.6311377 ,
#          0.88418646, -0.22537818]])

# %% [markdown]
# #### Evaluation and model training:

# %%
def evaluate_model(true, predicted):
    accuracy = accuracy_score(true, predicted)
    precision = precision_score(true, predicted, average='weighted')  # Update here
    recall = recall_score(true, predicted, average='weighted')  # Update here
    f1 = f1_score(true, predicted, average='weighted')  # Update here
    return accuracy, precision, recall, f1

# %%
models = {
    "Decision Tree": DecisionTreeClassifier(),
    "Random Forest": RandomForestClassifier(),
    "Support Vector Machine": SVC(),
    "K-Nearest Neighbors": KNeighborsClassifier(),
    "Logistic Regression": LogisticRegression(),
    "Gradient Boosting": GradientBoostingClassifier(),
    "Gaussian Naive Bayes": GaussianNB(),
    "Multilayer Perceptron": MLPClassifier(),
    "CatBoost Classifier": CatBoostClassifier(),
    "XGBoost Classifier": XGBClassifier()
}

model_list = []
accuracy_list = []

for model_name, model in models.items():
    model.fit(X_train, y_train) # Train model

    # Make predictions
    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)
    
    # Evaluate Train and Test dataset
    accuracy_train, precision_train, recall_train, f1_train = evaluate_model(y_train, y_train_pred)
    accuracy_test, precision_test, recall_test, f1_test = evaluate_model(y_test, y_test_pred)

    print(model_name)
    model_list.append(model_name)
    
    print('Model performance for Training set')
    print("- Accuracy: {:.4f}".format(accuracy_train))
    print("- Precision: {:.4f}".format(precision_train))
    print("- Recall: {:.4f}".format(recall_train))
    print("- F1 Score: {:.4f}".format(f1_train))
    print('----------------------------------')
    
    print('Model performance for Test set')
    print("- Accuracy: {:.4f}".format(accuracy_test))
    print("- Precision: {:.4f}".format(precision_test))
    print("- Recall: {:.4f}".format(recall_test))
    print("- F1 Score: {:.4f}".format(f1_test))
    print('='*35)
    print('\n')

    accuracy_list.append(model.score(X_test, y_test))
# Out:
# Decision Tree
# Model performance for Training set
# - Accuracy: 1.0000
# - Precision: 1.0000
# - Recall: 1.0000
# - F1 Score: 1.0000
# ----------------------------------
# Model performance for Test set
# - Accuracy: 1.0000
# - Precision: 1.0000
# - Recall: 1.0000
# - F1 Score: 1.0000
# ===================================
#
#
# Random Forest
# Model performance for Training set
# - Accuracy: 1.0000
# - Precision: 1.0000
# - Recall: 1.0000
# - F1 Score: 1.0000
# ----------------------------------
# Model performance for Test set
# - Accuracy: 1.0000
# - Precision: 1.0000
# - Recall: 1.0000
# - F1 Score: 1.0000
# ===================================
#
#
# Support Vector Machine
# Model performance for Training set
# - Accuracy: 1.0000
# - Precision: 1.0000
# - Recall: 1.0000
# - F1 Score: 1.0000
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.9963
# - Precision: 0.9963
# - Recall: 0.9963
# - F1 Score: 0.9963
# ===================================
#
#
# K-Nearest Neighbors
# Model performance for Training set
# - Accuracy: 0.9890
# - Precision: 0.9891
# - Recall: 0.9890
# - F1 Score: 0.9885
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.9890
# - Precision: 0.9891
# - Recall: 0.9890
# - F1 Score: 0.9887
# ===================================
#
#
# Logistic Regression
# Model performance for Training set
# - Accuracy: 1.0000
# - Precision: 1.0000
# - Recall: 1.0000
# - F1 Score: 1.0000
# ----------------------------------
# Model performance for Test set
# - Accuracy: 1.0000
# - Precision: 1.0000
# - Recall: 1.0000
# - F1 Score: 1.0000
# ===================================
#
#
# Gradient Boosting
# Model performance for Training set
# - Accuracy: 1.0000
# - Precision: 1.0000
# - Recall: 1.0000
# - F1 Score: 1.0000
# ----------------------------------
# Model performance for Test set
# - Accuracy: 1.0000
# - Precision: 1.0000
# - Recall: 1.0000
# - F1 Score: 1.0000
# ===================================
#
#
# Gaussian Naive Bayes
# Model performance for Training set
# - Accuracy: 1.0000
# - Precision: 1.0000
# - Recall: 1.0000
# - F1 Score: 1.0000
# ----------------------------------
# Model performance for Test set
# - Accuracy: 1.0000
# - Precision: 1.0000
# - Recall: 1.0000
# - F1 Score: 1.0000
# ===================================
#
#
# Multilayer Perceptron
# Model performance for Training set
# - Accuracy: 1.0000
# - Precision: 1.0000
# - Recall: 1.0000
# - F1 Score: 1.0000
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.9963
# - Precision: 0.9963
# - Recall: 0.9963
# - F1 Score: 0.9963
# ===================================
#
#
# Learning rate set to 0.079464
# 0:	learn: 0.9616873	total: 143ms	remaining: 2m 22s
# 1:	learn: 0.8507430	total: 147ms	remaining: 1m 13s
# 2:	learn: 0.7599621	total: 151ms	remaining: 50.2s
# 3:	learn: 0.6777414	total: 155ms	remaining: 38.5s
# 4:	learn: 0.6077261	total: 157ms	remaining: 31.2s
# 5:	learn: 0.5513941	total: 162ms	remaining: 26.9s
# 6:	learn: 0.4996991	total: 167ms	remaining: 23.8s
# 7:	learn: 0.4533942	total: 172ms	remaining: 21.3s
# 8:	learn: 0.4137263	total: 176ms	remaining: 19.4s
# 9:	learn: 0.3761021	total: 180ms	remaining: 17.9s
# 10:	learn: 0.3444367	total: 184ms	remaining: 16.5s
# 11:	learn: 0.3144831	total: 186ms	remaining: 15.3s
# 12:	learn: 0.2898540	total: 190ms	remaining: 14.4s
# 13:	learn: 0.2669705	total: 195ms	remaining: 13.7s
# 14:	learn: 0.2460793	total: 198ms	remaining: 13s
# 15:	learn: 0.2272428	total: 201ms	remaining: 12.4s
# 16:	learn: 0.2101252	total: 205ms	remaining: 11.8s
# 17:	learn: 0.1945093	total: 209ms	remaining: 11.4s
# 18:	learn: 0.1804168	total: 214ms	remaining: 11s
# 19:	learn: 0.1675702	total: 217ms	remaining: 10.6s
# 20:	learn: 0.1560023	total: 219ms	remaining: 10.2s
# 21:	learn: 0.1452382	total: 223ms	remaining: 9.93s
# 22:	learn: 0.1348685	total: 227ms	remaining: 9.65s
# 23:	learn: 0.1260895	total: 231ms	remaining: 9.38s
# 24:	learn: 0.1170867	total: 233ms	remaining: 9.09s
# 25:	learn: 0.1082898	total: 235ms	remaining: 8.79s
# 26:	learn: 0.1003332	total: 237ms	remaining: 8.53s
# 27:	learn: 0.0936504	total: 241ms	remaining: 8.36s
# 28:	learn: 0.0880554	total: 244ms	remaining: 8.16s
# 29:	learn: 0.0815333	total: 245ms	remaining: 7.92s
# 30:	learn: 0.0768601	total: 248ms	remaining: 7.74s
# 31:	learn: 0.0718324	total: 251ms	remaining: 7.59s
# 32:	learn: 0.0670759	total: 255ms	remaining: 7.46s
# 33:	learn: 0.0630451	total: 257ms	remaining: 7.31s
# 34:	learn: 0.0593573	total: 260ms	remaining: 7.17s
# 35:	learn: 0.0559315	total: 263ms	remaining: 7.03s
# 36:	learn: 0.0528974	total: 266ms	remaining: 6.91s
# 37:	learn: 0.0498466	total: 268ms	remaining: 6.78s
# 279:	learn: 0.0015264	total: 988ms	remaining: 2.54s
# 280:	learn: 0.0015217	total: 991ms	remaining: 2.53s
# 281:	learn: 0.0015161	total: 993ms	remaining: 2.53s
# 282:	learn: 0.0015092	total: 996ms	remaining: 2.52s
# 283:	learn: 0.0015045	total: 998ms	remaining: 2.52s
# 284:	learn: 0.0015008	total: 1s	remaining: 2.51s
# 285:	learn: 0.0014965	total: 1s	remaining: 2.5s
# 286:	learn: 0.0014912	total: 1s	remaining: 2.5s
# 287:	learn: 0.0014862	total: 1.01s	remaining: 2.49s
# 288:	learn: 0.0014793	total: 1.01s	remaining: 2.48s
# 289:	learn: 0.0014723	total: 1.01s	remaining: 2.48s
# 290:	learn: 0.0014656	total: 1.01s	remaining: 2.47s
# 291:	learn: 0.0014577	total: 1.02s	remaining: 2.46s
# 292:	learn: 0.0014517	total: 1.02s	remaining: 2.46s
# 293:	learn: 0.0014469	total: 1.02s	remaining: 2.45s
# 294:	learn: 0.0014420	total: 1.02s	remaining: 2.45s
# 295:	learn: 0.0014361	total: 1.03s	remaining: 2.44s
# 296:	learn: 0.0014316	total: 1.03s	remaining: 2.44s
# 297:	learn: 0.0014260	total: 1.03s	remaining: 2.43s
# 298:	learn: 0.0014221	total: 1.03s	remaining: 2.42s
# 299:	learn: 0.0014166	total: 1.03s	remaining: 2.42s
# 300:	learn: 0.0014092	total: 1.04s	remaining: 2.41s
# 301:	learn: 0.0014027	total: 1.04s	remaining: 2.41s
# 302:	learn: 0.0013987	total: 1.04s	remaining: 2.4s
# 303:	learn: 0.0013928	total: 1.05s	remaining: 2.4s
# 304:	learn: 0.0013887	total: 1.05s	remaining: 2.39s
# 305:	learn: 0.0013849	total: 1.05s	remaining: 2.38s
# 306:	learn: 0.0013800	total: 1.05s	remaining: 2.38s
# 307:	learn: 0.0013757	total: 1.06s	remaining: 2.37s
# 308:	learn: 0.0013714	total: 1.06s	remaining: 2.37s
# 309:	learn: 0.0013674	total: 1.06s	remaining: 2.36s
# 310:	learn: 0.0013644	total: 1.06s	remaining: 2.35s
# 311:	learn: 0.0013572	total: 1.06s	remaining: 2.35s
# 312:	learn: 0.0013515	total: 1.07s	remaining: 2.34s
# 313:	learn: 0.0013465	total: 1.07s	remaining: 2.34s
# 314:	learn: 0.0013403	total: 1.07s	remaining: 2.33s
# 315:	learn: 0.0013358	total: 1.07s	remaining: 2.33s
# 316:	learn: 0.0013322	total: 1.08s	remaining: 2.32s
# 317:	learn: 0.0013277	total: 1.08s	remaining: 2.32s
# 318:	learn: 0.0013250	total: 1.08s	remaining: 2.31s
# 319:	learn: 0.0013220	total: 1.09s	remaining: 2.31s
# 320:	learn: 0.0013187	total: 1.09s	remaining: 2.3s
# 321:	learn: 0.0013132	total: 1.09s	remaining: 2.3s
# 322:	learn: 0.0013094	total: 1.09s	remaining: 2.29s
# 323:	learn: 0.0013060	total: 1.1s	remaining: 2.29s
# 324:	learn: 0.0013033	total: 1.1s	remaining: 2.28s
# 325:	learn: 0.0013005	total: 1.1s	remaining: 2.28s
# 373:	learn: 0.0011288	total: 1.25s	remaining: 2.09s
# 374:	learn: 0.0011250	total: 1.25s	remaining: 2.08s
# 375:	learn: 0.0011225	total: 1.25s	remaining: 2.08s
# 376:	learn: 0.0011186	total: 1.26s	remaining: 2.08s
# 377:	learn: 0.0011151	total: 1.26s	remaining: 2.08s
# 378:	learn: 0.0011123	total: 1.26s	remaining: 2.07s
# 379:	learn: 0.0011104	total: 1.27s	remaining: 2.07s
# 380:	learn: 0.0011079	total: 1.27s	remaining: 2.07s
# 381:	learn: 0.0011057	total: 1.28s	remaining: 2.06s
# 382:	learn: 0.0011025	total: 1.28s	remaining: 2.06s
# 383:	learn: 0.0010999	total: 1.28s	remaining: 2.06s
# 384:	learn: 0.0010969	total: 1.28s	remaining: 2.05s
# 385:	learn: 0.0010939	total: 1.29s	remaining: 2.05s
# 386:	learn: 0.0010917	total: 1.29s	remaining: 2.05s
# 387:	learn: 0.0010894	total: 1.3s	remaining: 2.04s
# 388:	learn: 0.0010867	total: 1.3s	remaining: 2.04s
# 389:	learn: 0.0010848	total: 1.3s	remaining: 2.04s
# 390:	learn: 0.0010829	total: 1.31s	remaining: 2.04s
# 391:	learn: 0.0010810	total: 1.31s	remaining: 2.03s
# 392:	learn: 0.0010786	total: 1.31s	remaining: 2.03s
# 393:	learn: 0.0010750	total: 1.31s	remaining: 2.02s
# 394:	learn: 0.0010722	total: 1.32s	remaining: 2.02s
# 395:	learn: 0.0010699	total: 1.32s	remaining: 2.02s
# 396:	learn: 0.0010664	total: 1.33s	remaining: 2.02s
# 397:	learn: 0.0010637	total: 1.33s	remaining: 2.01s
# 398:	learn: 0.0010599	total: 1.33s	remaining: 2.01s
# 399:	learn: 0.0010573	total: 1.34s	remaining: 2.01s
# 400:	learn: 0.0010550	total: 1.34s	remaining: 2s
# 401:	learn: 0.0010525	total: 1.34s	remaining: 2s
# 402:	learn: 0.0010501	total: 1.35s	remaining: 2s
# 403:	learn: 0.0010475	total: 1.35s	remaining: 2s
# 404:	learn: 0.0010443	total: 1.36s	remaining: 1.99s
# 405:	learn: 0.0010414	total: 1.36s	remaining: 1.99s
# 406:	learn: 0.0010384	total: 1.36s	remaining: 1.99s
# 407:	learn: 0.0010359	total: 1.37s	remaining: 1.98s
# 408:	learn: 0.0010332	total: 1.37s	remaining: 1.98s
# 409:	learn: 0.0010310	total: 1.37s	remaining: 1.98s
# 410:	learn: 0.0010285	total: 1.38s	remaining: 1.97s
# 411:	learn: 0.0010268	total: 1.38s	remaining: 1.97s
# 412:	learn: 0.0010236	total: 1.38s	remaining: 1.97s
# 413:	learn: 0.0010221	total: 1.39s	remaining: 1.96s
# 414:	learn: 0.0010203	total: 1.39s	remaining: 1.96s
# 415:	learn: 0.0010182	total: 1.39s	remaining: 1.95s
# 416:	learn: 0.0010167	total: 1.39s	remaining: 1.95s
# 417:	learn: 0.0010151	total: 1.39s	remaining: 1.94s
# 418:	learn: 0.0010131	total: 1.4s	remaining: 1.94s
# 419:	learn: 0.0010117	total: 1.4s	remaining: 1.94s
# 654:	learn: 0.0006542	total: 2.31s	remaining: 1.22s
# 655:	learn: 0.0006530	total: 2.31s	remaining: 1.21s
# 656:	learn: 0.0006519	total: 2.32s	remaining: 1.21s
# 657:	learn: 0.0006507	total: 2.32s	remaining: 1.21s
# 658:	learn: 0.0006499	total: 2.33s	remaining: 1.2s
# 659:	learn: 0.0006485	total: 2.33s	remaining: 1.2s
# 660:	learn: 0.0006473	total: 2.34s	remaining: 1.2s
# 661:	learn: 0.0006465	total: 2.35s	remaining: 1.2s
# 662:	learn: 0.0006458	total: 2.35s	remaining: 1.2s
# 663:	learn: 0.0006450	total: 2.35s	remaining: 1.19s
# 664:	learn: 0.0006442	total: 2.36s	remaining: 1.19s
# 665:	learn: 0.0006433	total: 2.36s	remaining: 1.18s
# 666:	learn: 0.0006424	total: 2.37s	remaining: 1.18s
# 667:	learn: 0.0006417	total: 2.37s	remaining: 1.18s
# 668:	learn: 0.0006409	total: 2.38s	remaining: 1.18s
# 669:	learn: 0.0006400	total: 2.38s	remaining: 1.17s
# 670:	learn: 0.0006380	total: 2.38s	remaining: 1.17s
# 671:	learn: 0.0006368	total: 2.39s	remaining: 1.17s
# 672:	learn: 0.0006359	total: 2.39s	remaining: 1.16s
# 673:	learn: 0.0006348	total: 2.39s	remaining: 1.16s
# 674:	learn: 0.0006339	total: 2.4s	remaining: 1.15s
# 675:	learn: 0.0006331	total: 2.41s	remaining: 1.15s
# 676:	learn: 0.0006319	total: 2.41s	remaining: 1.15s
# 677:	learn: 0.0006312	total: 2.42s	remaining: 1.15s
# 678:	learn: 0.0006305	total: 2.42s	remaining: 1.14s
# 679:	learn: 0.0006299	total: 2.42s	remaining: 1.14s
# 680:	learn: 0.0006285	total: 2.43s	remaining: 1.14s
# 681:	learn: 0.0006275	total: 2.43s	remaining: 1.13s
# 682:	learn: 0.0006269	total: 2.44s	remaining: 1.13s
# 683:	learn: 0.0006262	total: 2.44s	remaining: 1.13s
# 684:	learn: 0.0006253	total: 2.44s	remaining: 1.12s
# 685:	learn: 0.0006242	total: 2.45s	remaining: 1.12s
# 686:	learn: 0.0006233	total: 2.45s	remaining: 1.12s
# 687:	learn: 0.0006226	total: 2.46s	remaining: 1.11s
# 688:	learn: 0.0006213	total: 2.46s	remaining: 1.11s
# 689:	learn: 0.0006202	total: 2.46s	remaining: 1.11s
# 690:	learn: 0.0006189	total: 2.47s	remaining: 1.1s
# 691:	learn: 0.0006183	total: 2.47s	remaining: 1.1s
# 692:	learn: 0.0006175	total: 2.48s	remaining: 1.1s
# 693:	learn: 0.0006168	total: 2.48s	remaining: 1.09s
# 694:	learn: 0.0006159	total: 2.48s	remaining: 1.09s
# 695:	learn: 0.0006145	total: 2.49s	remaining: 1.09s
# 696:	learn: 0.0006139	total: 2.49s	remaining: 1.08s
# 697:	learn: 0.0006130	total: 2.49s	remaining: 1.08s
# 698:	learn: 0.0006119	total: 2.5s	remaining: 1.07s
# 699:	learn: 0.0006109	total: 2.5s	remaining: 1.07s
# 988:	learn: 0.0004355	total: 3.47s	remaining: 38.6ms
# 989:	learn: 0.0004350	total: 3.48s	remaining: 35.1ms
# 990:	learn: 0.0004346	total: 3.48s	remaining: 31.6ms
# 991:	learn: 0.0004342	total: 3.48s	remaining: 28.1ms
# 992:	learn: 0.0004336	total: 3.49s	remaining: 24.6ms
# 993:	learn: 0.0004330	total: 3.49s	remaining: 21.1ms
# 994:	learn: 0.0004326	total: 3.5s	remaining: 17.6ms
# 995:	learn: 0.0004323	total: 3.5s	remaining: 14.1ms
# 996:	learn: 0.0004320	total: 3.5s	remaining: 10.5ms
# 997:	learn: 0.0004317	total: 3.51s	remaining: 7.03ms
# 998:	learn: 0.0004313	total: 3.51s	remaining: 3.51ms
# 999:	learn: 0.0004307	total: 3.51s	remaining: 0us
# CatBoost Classifier
# Model performance for Training set
# - Accuracy: 1.0000
# - Precision: 1.0000
# - Recall: 1.0000
# - F1 Score: 1.0000
# ----------------------------------
# Model performance for Test set
# - Accuracy: 1.0000
# - Precision: 1.0000
# - Recall: 1.0000
# - F1 Score: 1.0000
# ===================================
#
#
# XGBoost Classifier
# Model performance for Training set
# - Accuracy: 1.0000
# - Precision: 1.0000
# - Recall: 1.0000
# - F1 Score: 1.0000
# ----------------------------------
# Model performance for Test set
# - Accuracy: 1.0000
# - Precision: 1.0000
# - Recall: 1.0000
# - F1 Score: 1.0000
# ===================================

# %%
results = pd.DataFrame(list(zip(model_list, accuracy_list)), 
                       columns=['Model Name', 'Accuracy']).sort_values(by=["Accuracy"],
                                                                       ascending=False)
results
# Out:
#                Model Name  Accuracy
# 0           Decision Tree  1.000000
# 1           Random Forest  1.000000
# 4     Logistic Regression  1.000000
# 5       Gradient Boosting  1.000000
# 6    Gaussian Naive Bayes  1.000000
# 8     CatBoost Classifier  1.000000
# 9      XGBoost Classifier  1.000000
# 2  Support Vector Machine  0.996324
# 7   Multilayer Perceptron  0.996324
# 3     K-Nearest Neighbors  0.988971

# %% [markdown]
# ### Top 4 Models Selection for Industry Readiness
#
# Considering computational efficiency, interpretability, scalability, and robustness, the following top 4 models are selected for further tuning and industry readiness:
#
# 1. **Decision Tree:**
#    - **Reasoning:** Decision trees are computationally efficient, interpretable, and suitable for tasks where transparency is crucial. They are well-suited for decision-making processes and require minimal preprocessing.
#
# 2. **Random Forest:**
#    - **Reasoning:** Random Forest combines the simplicity of decision trees with improved accuracy and robustness. It generalizes well to unseen data and is efficient for large-scale datasets, common in industry applications.
#
# 3. **Logistic Regression:**
#    - **Reasoning:** Logistic Regression is simple, interpretable, and computationally efficient. It provides probabilistic outputs and works well for binary classification tasks, making it suitable for applications where transparency and simplicity are prioritized.
#
# 4. **Gradient Boosting:**
#    - **Reasoning:** Gradient Boosting models like XGBoost and CatBoost offer superior performance and scalability. Despite being more complex, they are optimized for efficiency and robustness, making them suitable for industry-scale applications.
#
# **Why These Models:**
#
# - **Interpretability:** Decision trees, Logistic Regression, and ensemble methods like Random Forests provide interpretability, crucial for understanding model decisions in industry settings.
#
# - **Scalability:** Gradient Boosting methods are scalable and efficient, capable of handling large-scale datasets commonly encountered in industry applications.
#
# - **Robustness:** Random Forests and Gradient Boosting models are robust against overfitting and generalize well to unseen data, ensuring reliable performance in real-world scenarios.
#
# - **Ease of Deployment:** All selected models are relatively easy to deploy in production environments, with mature implementations available in popular machine learning libraries and frameworks.
#
# Focusing on these top 4 models strikes a balance between computational efficiency, interpretability, scalability, and robustness, ensuring readiness for deployment in real-world industry applications. Further tuning and optimization can enhance their performance and suitability for specific use cases.
# gration into your pipeline.
