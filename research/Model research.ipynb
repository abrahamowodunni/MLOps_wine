# %% [markdown]
# # Model Training Research: Candidate Models and Considerations
#
# This document outlines candidate models to be considered for our wine quality prediction task, along with key factors to evaluate during the research phase.
#
# ## Candidate Models
#
# Here are some potential machine learning models that could be explored for predicting wine quality:
#
# 1. **Decision Trees:**
#    - **Strengths:** Flexible and can handle both continuous and categorical features without extensive data preprocessing. Robust to outliers.
#    - **Weaknesses:** Prone to overfitting if not properly tuned. Can be less interpretable than linear models.
#
# 2. **Random Forests:**
#    - **Strengths:** Ensemble method combining multiple decision trees, leading to improved accuracy and reduced overfitting compared to single decision trees.
#    - **Weaknesses:** Interpretability can be challenging due to the ensemble nature. May require hyperparameter tuning for optimal performance.
#
# 3. **Support Vector Machines (SVMs):**
#    - **Strengths:** Powerful for classification tasks, especially with high-dimensional data. Effective at handling non-linear relationships using kernel functions.
#    - **Weaknesses:** Sensitive to outliers and feature scaling. Can be computationally expensive for large datasets.
#
# 4. **K-Nearest Neighbors (KNN):**
#    - **Strengths:** Simple and easy to implement. No explicit model training required. Effective for both classification and regression.
#    - **Weaknesses:** Performance can be affected by the "curse of dimensionality." Sensitive to noisy data and choice of distance metric.
#
# 5. **Logistic Regression:**
#    - **Strengths:** Simple and interpretable. Suitable for binary classification tasks. Can handle large datasets efficiently.
#    - **Weaknesses:** Assumes linear relationship between features and target variable. May underperform if the data is not linearly separable.
#
# 6. **Gradient Boosting Machines (GBM):**
#    - **Strengths:** Builds decision trees sequentially, focusing on correcting errors made by previous trees. Typically achieves high accuracy.
#    - **Weaknesses:** Prone to overfitting if not properly regularized. Requires careful tuning of hyperparameters.
#
# 7. **Naive Bayes:**
#    - **Strengths:** Simple and fast to train. Performs well on text classification tasks and with categorical features.
#    - **Weaknesses:** Assumes independence between features, which may not hold true in practice. Can be sensitive to imbalanced class distributions.
#
# 8. **Neural Networks:**
#    - **Strengths:** Capable of learning complex patterns in data. Can handle high-dimensional inputs and non-linear relationships.
#    - **Weaknesses:** Requires large amounts of data for training. May suffer from overfitting if not properly regularized. Computationally intensive.
#
# ## Selection Criteria
#
# When evaluating these models, we should consider the following factors:
#
# - **Problem Type:** Since we're predicting wine quality (likely a categorical variable), we'll be focusing on classification models.
# - **Data Characteristics:**
#   - Feature types (continuous, categorical)
#   - Data size and dimensionality
#   - Presence of missing values or outliers
# - **Model Performance:**
#   - Accuracy, precision, recall, F1-score (depending on class imbalance)
#   - Overfitting potential
# - **Interpretability:**
#   - Importance of understanding model predictions and feature relationships
#   - Trade-off between accuracy and interpretability
#
# ## Research Plan
#
# The research will involve:
#
# 1. **Data Preprocessing:** Exploring data cleaning, handling missing values, and feature scaling if necessary.
# 2. **Model Training and Evaluation:** Implementing and training each candidate model with appropriate hyperparameter tuning. Evaluating performance metrics on a separate validation set.
# 3. **Model Selection:** Choosing the model with the best balance of accuracy, interpretability, and suitability for the data.
# 4. **Model Interpretation:** Analyzing the chosen model to understand how features influence predictions (if applicable).
#
# Through this research, we aim to identify the most effective model for predicting wine quality based on the given dataset and evaluation criteria.
# ed on the given dataset and evaluation criteria.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier
from catboost import CatBoostClassifier
from xgboost import XGBClassifier

# %%
df = pd.read_csv("new_df_wine.csv")
df = df.drop('Unnamed: 0',axis = 1)
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.66         0.00             1.8      0.075
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 13.0                  40.0   0.9978  3.51       0.56
#
#    alcohol quality
# 0      9.4  medium
# 1      9.8  medium
# 2      9.8  medium
# 3      9.8  medium
# 4      9.4  medium

# %% [markdown]
# I will encode my target variable since some of the models can handle categorical data...

# %%
label_mapping = {'low': 0, 'medium': 1, 'high': 2}
# Map the labels to numerical values
df['quality'] = df['quality'].map(label_mapping)
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.66         0.00             1.8      0.075
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 13.0                  40.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        1
# 1      9.8        1
# 2      9.8        1
# 3      9.8        1
# 4      9.4        1

# %% [markdown]
# #### Train test split
# Doing this now to avoid data leakage.

# %%
def train_test(df,target_column,test_size,random_state):
    """
    Perform train-test split on a DataFrame.
    
    Parameters:
    df (DataFrame): The DataFrame containing features and target variable.
    target_variable (str): The name of the target variable.
    random_state (int): Random state for reproducibility.
    test_size (float): The proportion of the dataset to include in the test split.
    
    Returns:
    X_train (DataFrame): The features for training.
    X_test (DataFrame): The features for testing.
    y_train (Series): The target variable for training.
    y_test (Series): The target variable for testing.
    """
    X = df.drop(target_column,axis = 1)
    y = df[target_column]

    X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=test_size,random_state=random_state)
    return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = train_test(df,'quality',0.2,42)

# %%
X_train.shape, y_test.shape
# Out:
# ((1087, 11), (272,))

# %%
y_train
# Out:
# 865     2
# 1289    1
# 394     1
# 731     1
# 54      1
#        ..
# 1095    1
# 1130    1
# 1294    1
# 860     1
# 1126    1
# Name: quality, Length: 1087, dtype: int64

# %%
len(list(X_train.columns))
# Out:
# 11

# %%
len(X_train.select_dtypes(exclude="object").columns)
# Out:
# 11

# %%
from sklearn.compose import ColumnTransformer
num_features = list(X_train.columns)
numeric_transformer = StandardScaler()

# %%
preprocessor = ColumnTransformer(
    [
         ("StandardScaler", numeric_transformer, num_features)       
    ]
)

# %%
X_train = preprocessor.fit_transform(X_train)
X_test = preprocessor.transform(X_test)

X_train.shape,X_test.shape
# Out:
# ((1087, 11), (272, 11))

# %%
X_train,X_test
# Out:
# (array([[ 0.35162311, -0.82832312,  0.64877105, ..., -0.25982192,
#           0.51985077,  1.98424001],
#         [-0.98154785,  0.96589124, -0.98983279, ...,  0.85726724,
#          -0.45848943, -0.2158671 ],
#         [-0.86561994,  0.18092246, -1.24586464, ...,  0.85726724,
#          -0.17074231, -0.39920936],
#         ...,
#         [-0.86561994, -0.32370033, -0.98983279, ..., -0.06268854,
#          -0.05564346, -0.76589387],
#         [ 0.35162311, -1.16473831,  0.18791372, ..., -0.91693319,
#          -0.6311377 , -0.03252484],
#         [ 0.46755102, -1.05259991,  0.75118379, ..., -0.85122206,
#          -0.6311377 ,  0.88418646]]),
#  array([[-0.34394435,  0.51733765, -1.19465827, ...,  0.20015597,
#          -0.74623655, -0.857565  ],
#         [-0.05412458,  0.60144145, -0.88742005, ..., -0.12839966,
#           0.51985077,  0.42583081],
#         [ 0.06180333, -0.88439232,  0.80239016, ..., -0.91693319,
#           0.86514732,  0.7008442 ],
#         ...,
#         [ 0.35162311, -0.71618472,  0.23912009, ...,  0.46300048,
#           0.63494962,  0.05914629],
#         [-1.67711531, -0.60404632, -0.01691176, ...,  3.09144557,
#          -0.11319289,  1.70922662],
#         [-0.05412458,  0.34913006, -1.39948375, ...,  1.25153401,
#          -0.05564346, -1.04090726]]))

# %%
y_train
# Out:
# 865     2
# 1289    1
# 394     1
# 731     1
# 54      1
#        ..
# 1095    1
# 1130    1
# 1294    1
# 860     1
# 1126    1
# Name: quality, Length: 1087, dtype: int64

# %% [markdown]
# #### Evaluation and model training:

# %%
def evaluate_model(true, predicted):
    accuracy = accuracy_score(true, predicted)
    precision = precision_score(true, predicted, average='weighted')  # Update here
    recall = recall_score(true, predicted, average='weighted')  # Update here
    f1 = f1_score(true, predicted, average='weighted')  # Update here
    return accuracy, precision, recall, f1

# %%
models = {
    "Decision Tree": DecisionTreeClassifier(),
    "Random Forest": RandomForestClassifier(),
    "Support Vector Machine": SVC(),
    "K-Nearest Neighbors": KNeighborsClassifier(),
    "Logistic Regression": LogisticRegression(),
    "Gradient Boosting": GradientBoostingClassifier(),
    "Gaussian Naive Bayes": GaussianNB(),
    "Multilayer Perceptron": MLPClassifier(),
    "CatBoost Classifier": CatBoostClassifier(),
    "XGBoost Classifier": XGBClassifier()
}

model_list = []
accuracy_list = []
_accuracy_train = []

for model_name, model in models.items():
    model.fit(X_train, y_train) # Train model

    # Make predictions
    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)
    
    # Evaluate Train and Test dataset
    accuracy_train, precision_train, recall_train, f1_train = evaluate_model(y_train, y_train_pred)
    accuracy_test, precision_test, recall_test, f1_test = evaluate_model(y_test, y_test_pred)

    print(model_name)
    model_list.append(model_name)
    
    print('Model performance for Training set')
    print("- Accuracy: {:.4f}".format(accuracy_train))
    print("- Precision: {:.4f}".format(precision_train))
    print("- Recall: {:.4f}".format(recall_train))
    print("- F1 Score: {:.4f}".format(f1_train))
    print('----------------------------------')
    
    print('Model performance for Test set')
    print("- Accuracy: {:.4f}".format(accuracy_test))
    print("- Precision: {:.4f}".format(precision_test))
    print("- Recall: {:.4f}".format(recall_test))
    print("- F1 Score: {:.4f}".format(f1_test))
    print('='*35)
    print('\n')

    _accuracy_train.append(accuracy_train)
    accuracy_list.append(accuracy_test)
# Out:
# Decision Tree
# Model performance for Training set
# - Accuracy: 1.0000
# - Precision: 1.0000
# - Recall: 1.0000
# - F1 Score: 1.0000
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.7574
# - Precision: 0.7615
# - Recall: 0.7574
# - F1 Score: 0.7592
# ===================================
# C:\Users\mayuo\anaconda3\envs\machineLearning\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mayuo\anaconda3\envs\machineLearning\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Random Forest
# Model performance for Training set
# - Accuracy: 1.0000
# - Precision: 1.0000
# - Recall: 1.0000
# - F1 Score: 1.0000
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.8529
# - Precision: 0.7997
# - Recall: 0.8529
# - F1 Score: 0.8150
# ===================================
#
#
# Support Vector Machine
# Model performance for Training set
# - Accuracy: 0.8445
# - Precision: 0.8426
# - Recall: 0.8445
# - F1 Score: 0.8025
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.8640
# - Precision: 0.8125
# - Recall: 0.8640
# - F1 Score: 0.8301
# ===================================
#
#
# K-Nearest Neighbors
# Model performance for Training set
# - Accuracy: 0.8638
# - Precision: 0.8460
# - Recall: 0.8638
# - F1 Score: 0.8451
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.8199
# - Precision: 0.7761
# - Recall: 0.8199
# - F1 Score: 0.7966
# ===================================
#
#
# Logistic Regression
# Model performance for Training set
# - Accuracy: 0.8362
# - Precision: 0.8161
# - Recall: 0.8362
# - F1 Score: 0.8049
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.8382
# - Precision: 0.8096
# - Recall: 0.8382
# - F1 Score: 0.8090
# ===================================
#
#
# Gradient Boosting
# Model performance for Training set
# - Accuracy: 0.9641
# - Precision: 0.9653
# - Recall: 0.9641
# - F1 Score: 0.9626
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.8640
# - Precision: 0.8358
# - Recall: 0.8640
# - F1 Score: 0.8415
# ===================================
#
#
# Gaussian Naive Bayes
# Model performance for Training set
# - Accuracy: 0.7626
# - Precision: 0.8000
# - Recall: 0.7626
# - F1 Score: 0.7753
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.7978
# - Precision: 0.8176
# - Recall: 0.7978
# - F1 Score: 0.8031
# ===================================
# C:\Users\mayuo\anaconda3\envs\machineLearning\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Multilayer Perceptron
# Model performance for Training set
# - Accuracy: 0.8712
# - Precision: 0.8601
# - Recall: 0.8712
# - F1 Score: 0.8535
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.8456
# - Precision: 0.8282
# - Recall: 0.8456
# - F1 Score: 0.8272
# ===================================
#
#
# Learning rate set to 0.079464
# 0:	learn: 1.0161531	total: 4.06ms	remaining: 4.05s
# 1:	learn: 0.9523774	total: 7.53ms	remaining: 3.76s
# 2:	learn: 0.8944809	total: 11.6ms	remaining: 3.84s
# 3:	learn: 0.8453778	total: 16.1ms	remaining: 4.01s
# 4:	learn: 0.8029076	total: 20.5ms	remaining: 4.08s
# 5:	learn: 0.7652276	total: 24.4ms	remaining: 4.05s
# 6:	learn: 0.7325721	total: 29ms	remaining: 4.11s
# 7:	learn: 0.7032581	total: 33.7ms	remaining: 4.17s
# 8:	learn: 0.6784298	total: 38.1ms	remaining: 4.2s
# 9:	learn: 0.6550096	total: 41.9ms	remaining: 4.15s
# 10:	learn: 0.6338475	total: 45.7ms	remaining: 4.11s
# 11:	learn: 0.6137057	total: 50.2ms	remaining: 4.13s
# 12:	learn: 0.5969070	total: 53.7ms	remaining: 4.08s
# 13:	learn: 0.5800949	total: 57.5ms	remaining: 4.05s
# 14:	learn: 0.5672320	total: 60.8ms	remaining: 4s
# 15:	learn: 0.5541915	total: 64.9ms	remaining: 3.99s
# 16:	learn: 0.5417990	total: 68.3ms	remaining: 3.95s
# 17:	learn: 0.5303181	total: 71.9ms	remaining: 3.92s
# 18:	learn: 0.5211046	total: 76.1ms	remaining: 3.93s
# 19:	learn: 0.5120977	total: 80ms	remaining: 3.92s
# 20:	learn: 0.5053633	total: 83.6ms	remaining: 3.9s
# 21:	learn: 0.4980536	total: 87ms	remaining: 3.87s
# 22:	learn: 0.4908866	total: 90.6ms	remaining: 3.85s
# 23:	learn: 0.4828620	total: 94.3ms	remaining: 3.83s
# 24:	learn: 0.4764476	total: 97.8ms	remaining: 3.81s
# 25:	learn: 0.4700592	total: 102ms	remaining: 3.81s
# 26:	learn: 0.4644512	total: 105ms	remaining: 3.8s
# 27:	learn: 0.4587055	total: 109ms	remaining: 3.8s
# 28:	learn: 0.4535281	total: 113ms	remaining: 3.8s
# 29:	learn: 0.4494890	total: 117ms	remaining: 3.78s
# 30:	learn: 0.4458022	total: 121ms	remaining: 3.77s
# 31:	learn: 0.4421683	total: 124ms	remaining: 3.75s
# 32:	learn: 0.4371967	total: 128ms	remaining: 3.75s
# 33:	learn: 0.4338400	total: 131ms	remaining: 3.72s
# 34:	learn: 0.4299966	total: 135ms	remaining: 3.71s
# 35:	learn: 0.4257681	total: 138ms	remaining: 3.7s
# 36:	learn: 0.4219371	total: 141ms	remaining: 3.68s
# 37:	learn: 0.4192077	total: 145ms	remaining: 3.67s
# 38:	learn: 0.4157902	total: 148ms	remaining: 3.66s
# 39:	learn: 0.4117423	total: 152ms	remaining: 3.64s
# 40:	learn: 0.4083555	total: 155ms	remaining: 3.63s
# 41:	learn: 0.4052298	total: 159ms	remaining: 3.63s
# 42:	learn: 0.4031017	total: 163ms	remaining: 3.63s
# 43:	learn: 0.4003292	total: 168ms	remaining: 3.64s
# 44:	learn: 0.3981239	total: 173ms	remaining: 3.66s
# 45:	learn: 0.3960700	total: 177ms	remaining: 3.68s
# 46:	learn: 0.3945868	total: 182ms	remaining: 3.69s
# 47:	learn: 0.3927244	total: 186ms	remaining: 3.69s
# 48:	learn: 0.3909549	total: 189ms	remaining: 3.68s
# 49:	learn: 0.3889582	total: 193ms	remaining: 3.67s
# 50:	learn: 0.3867899	total: 197ms	remaining: 3.66s
# 51:	learn: 0.3850903	total: 200ms	remaining: 3.65s
# 52:	learn: 0.3836531	total: 204ms	remaining: 3.64s
# 53:	learn: 0.3818848	total: 208ms	remaining: 3.64s
# 54:	learn: 0.3806329	total: 211ms	remaining: 3.63s
# 55:	learn: 0.3790545	total: 214ms	remaining: 3.62s
# 56:	learn: 0.3773598	total: 218ms	remaining: 3.6s
# 57:	learn: 0.3758444	total: 222ms	remaining: 3.6s
# 58:	learn: 0.3741524	total: 225ms	remaining: 3.59s
# 59:	learn: 0.3714033	total: 229ms	remaining: 3.58s
# 60:	learn: 0.3702536	total: 232ms	remaining: 3.58s
# 61:	learn: 0.3688325	total: 236ms	remaining: 3.56s
# 62:	learn: 0.3675477	total: 239ms	remaining: 3.56s
# 63:	learn: 0.3656961	total: 243ms	remaining: 3.55s
# 64:	learn: 0.3640704	total: 246ms	remaining: 3.54s
# 65:	learn: 0.3624011	total: 250ms	remaining: 3.53s
# 66:	learn: 0.3604936	total: 254ms	remaining: 3.53s
# 67:	learn: 0.3597396	total: 257ms	remaining: 3.52s
# 68:	learn: 0.3586431	total: 260ms	remaining: 3.51s
# 69:	learn: 0.3578266	total: 264ms	remaining: 3.5s
# 70:	learn: 0.3560773	total: 267ms	remaining: 3.5s
# 71:	learn: 0.3539671	total: 271ms	remaining: 3.5s
# 72:	learn: 0.3530150	total: 275ms	remaining: 3.49s
# 73:	learn: 0.3508611	total: 278ms	remaining: 3.48s
# 74:	learn: 0.3491111	total: 282ms	remaining: 3.48s
# 75:	learn: 0.3482218	total: 286ms	remaining: 3.48s
# 76:	learn: 0.3461322	total: 290ms	remaining: 3.47s
# 77:	learn: 0.3454350	total: 293ms	remaining: 3.46s
# 78:	learn: 0.3445367	total: 296ms	remaining: 3.46s
# 79:	learn: 0.3435301	total: 300ms	remaining: 3.46s
# 80:	learn: 0.3431133	total: 304ms	remaining: 3.45s
# 81:	learn: 0.3416887	total: 307ms	remaining: 3.44s
# 82:	learn: 0.3403949	total: 311ms	remaining: 3.43s
# 83:	learn: 0.3386006	total: 315ms	remaining: 3.43s
# 84:	learn: 0.3370879	total: 319ms	remaining: 3.43s
# 85:	learn: 0.3355561	total: 323ms	remaining: 3.44s
# 86:	learn: 0.3337214	total: 327ms	remaining: 3.43s
# 87:	learn: 0.3328607	total: 331ms	remaining: 3.43s
# 88:	learn: 0.3321327	total: 335ms	remaining: 3.42s
# 89:	learn: 0.3310283	total: 338ms	remaining: 3.42s
# 90:	learn: 0.3294816	total: 342ms	remaining: 3.41s
# 91:	learn: 0.3284269	total: 346ms	remaining: 3.41s
# 92:	learn: 0.3278729	total: 349ms	remaining: 3.4s
# 93:	learn: 0.3270342	total: 353ms	remaining: 3.4s
# 94:	learn: 0.3260866	total: 356ms	remaining: 3.39s
# 95:	learn: 0.3247764	total: 360ms	remaining: 3.39s
# 96:	learn: 0.3237805	total: 364ms	remaining: 3.39s
# 97:	learn: 0.3230257	total: 369ms	remaining: 3.39s
# 98:	learn: 0.3216277	total: 374ms	remaining: 3.4s
# 99:	learn: 0.3204448	total: 377ms	remaining: 3.4s
# 100:	learn: 0.3194243	total: 382ms	remaining: 3.4s
# 101:	learn: 0.3184378	total: 386ms	remaining: 3.4s
# 102:	learn: 0.3175273	total: 390ms	remaining: 3.4s
# 103:	learn: 0.3160421	total: 393ms	remaining: 3.39s
# 104:	learn: 0.3149702	total: 398ms	remaining: 3.39s
# 105:	learn: 0.3142906	total: 402ms	remaining: 3.39s
# 106:	learn: 0.3134363	total: 405ms	remaining: 3.38s
# 107:	learn: 0.3121580	total: 409ms	remaining: 3.38s
# 108:	learn: 0.3111154	total: 414ms	remaining: 3.38s
# 109:	learn: 0.3105862	total: 417ms	remaining: 3.38s
# 110:	learn: 0.3092650	total: 421ms	remaining: 3.37s
# 111:	learn: 0.3083235	total: 425ms	remaining: 3.37s
# 112:	learn: 0.3069098	total: 430ms	remaining: 3.37s
# 113:	learn: 0.3062105	total: 433ms	remaining: 3.37s
# 114:	learn: 0.3055840	total: 437ms	remaining: 3.37s
# 115:	learn: 0.3051828	total: 441ms	remaining: 3.36s
# 116:	learn: 0.3037540	total: 446ms	remaining: 3.37s
# 117:	learn: 0.3031283	total: 450ms	remaining: 3.36s
# 118:	learn: 0.3025686	total: 454ms	remaining: 3.36s
# 119:	learn: 0.3016329	total: 458ms	remaining: 3.36s
# 120:	learn: 0.3007482	total: 462ms	remaining: 3.35s
# 121:	learn: 0.2996274	total: 466ms	remaining: 3.35s
# 122:	learn: 0.2987123	total: 470ms	remaining: 3.35s
# 123:	learn: 0.2981539	total: 474ms	remaining: 3.35s
# 124:	learn: 0.2975207	total: 479ms	remaining: 3.35s
# 125:	learn: 0.2971779	total: 483ms	remaining: 3.35s
# 126:	learn: 0.2968187	total: 487ms	remaining: 3.35s
# 127:	learn: 0.2960896	total: 492ms	remaining: 3.35s
# 128:	learn: 0.2947299	total: 496ms	remaining: 3.35s
# 129:	learn: 0.2939566	total: 500ms	remaining: 3.34s
# 130:	learn: 0.2935002	total: 503ms	remaining: 3.34s
# 131:	learn: 0.2929906	total: 508ms	remaining: 3.34s
# 132:	learn: 0.2923218	total: 513ms	remaining: 3.34s
# 133:	learn: 0.2906814	total: 517ms	remaining: 3.34s
# 134:	learn: 0.2895644	total: 521ms	remaining: 3.33s
# 135:	learn: 0.2873536	total: 525ms	remaining: 3.33s
# 136:	learn: 0.2864619	total: 529ms	remaining: 3.33s
# 137:	learn: 0.2856408	total: 533ms	remaining: 3.33s
# 138:	learn: 0.2846241	total: 537ms	remaining: 3.33s
# 139:	learn: 0.2840284	total: 541ms	remaining: 3.33s
# 140:	learn: 0.2829567	total: 545ms	remaining: 3.32s
# 141:	learn: 0.2820913	total: 549ms	remaining: 3.31s
# 142:	learn: 0.2813842	total: 553ms	remaining: 3.31s
# 143:	learn: 0.2810399	total: 557ms	remaining: 3.31s
# 144:	learn: 0.2793145	total: 562ms	remaining: 3.31s
# 145:	learn: 0.2784779	total: 566ms	remaining: 3.31s
# 146:	learn: 0.2779756	total: 570ms	remaining: 3.31s
# 147:	learn: 0.2771528	total: 575ms	remaining: 3.31s
# 148:	learn: 0.2760711	total: 579ms	remaining: 3.31s
# 149:	learn: 0.2754597	total: 583ms	remaining: 3.3s
# 150:	learn: 0.2746221	total: 587ms	remaining: 3.3s
# 151:	learn: 0.2743941	total: 591ms	remaining: 3.3s
# 152:	learn: 0.2736315	total: 595ms	remaining: 3.29s
# 153:	learn: 0.2730581	total: 598ms	remaining: 3.29s
# 154:	learn: 0.2719519	total: 602ms	remaining: 3.28s
# 155:	learn: 0.2709988	total: 606ms	remaining: 3.28s
# 156:	learn: 0.2703295	total: 610ms	remaining: 3.27s
# 157:	learn: 0.2695611	total: 615ms	remaining: 3.27s
# 158:	learn: 0.2687946	total: 618ms	remaining: 3.27s
# 159:	learn: 0.2674479	total: 622ms	remaining: 3.27s
# 160:	learn: 0.2663961	total: 625ms	remaining: 3.26s
# 161:	learn: 0.2661034	total: 629ms	remaining: 3.25s
# 162:	learn: 0.2653401	total: 633ms	remaining: 3.25s
# 163:	learn: 0.2648273	total: 636ms	remaining: 3.24s
# 164:	learn: 0.2643557	total: 640ms	remaining: 3.24s
# 165:	learn: 0.2636094	total: 644ms	remaining: 3.23s
# 166:	learn: 0.2633016	total: 647ms	remaining: 3.23s
# 167:	learn: 0.2628725	total: 651ms	remaining: 3.22s
# 168:	learn: 0.2616998	total: 654ms	remaining: 3.22s
# 169:	learn: 0.2608824	total: 658ms	remaining: 3.21s
# 170:	learn: 0.2599425	total: 662ms	remaining: 3.21s
# 171:	learn: 0.2593591	total: 666ms	remaining: 3.21s
# 172:	learn: 0.2591799	total: 669ms	remaining: 3.2s
# 173:	learn: 0.2575996	total: 673ms	remaining: 3.19s
# 174:	learn: 0.2567565	total: 677ms	remaining: 3.19s
# 175:	learn: 0.2558792	total: 680ms	remaining: 3.19s
# 176:	learn: 0.2553393	total: 684ms	remaining: 3.18s
# 177:	learn: 0.2541562	total: 688ms	remaining: 3.17s
# 178:	learn: 0.2533588	total: 692ms	remaining: 3.17s
# 179:	learn: 0.2528084	total: 696ms	remaining: 3.17s
# 180:	learn: 0.2518538	total: 699ms	remaining: 3.16s
# 181:	learn: 0.2510401	total: 703ms	remaining: 3.16s
# 182:	learn: 0.2500404	total: 708ms	remaining: 3.16s
# 183:	learn: 0.2490765	total: 713ms	remaining: 3.16s
# 184:	learn: 0.2483577	total: 716ms	remaining: 3.15s
# 185:	learn: 0.2474116	total: 720ms	remaining: 3.15s
# 186:	learn: 0.2469038	total: 724ms	remaining: 3.15s
# 187:	learn: 0.2460491	total: 728ms	remaining: 3.14s
# 188:	learn: 0.2458348	total: 731ms	remaining: 3.14s
# 189:	learn: 0.2454682	total: 735ms	remaining: 3.13s
# 190:	learn: 0.2441753	total: 739ms	remaining: 3.13s
# 191:	learn: 0.2435225	total: 743ms	remaining: 3.13s
# 192:	learn: 0.2427756	total: 746ms	remaining: 3.12s
# 193:	learn: 0.2417560	total: 751ms	remaining: 3.12s
# 194:	learn: 0.2408963	total: 755ms	remaining: 3.12s
# 195:	learn: 0.2403300	total: 759ms	remaining: 3.11s
# 196:	learn: 0.2401984	total: 766ms	remaining: 3.12s
# 197:	learn: 0.2395541	total: 807ms	remaining: 3.27s
# 198:	learn: 0.2393739	total: 812ms	remaining: 3.27s
# 199:	learn: 0.2383203	total: 820ms	remaining: 3.28s
# 200:	learn: 0.2378549	total: 825ms	remaining: 3.28s
# 201:	learn: 0.2374456	total: 829ms	remaining: 3.27s
# 202:	learn: 0.2368336	total: 832ms	remaining: 3.27s
# 203:	learn: 0.2363753	total: 836ms	remaining: 3.26s
# 204:	learn: 0.2353213	total: 840ms	remaining: 3.26s
# 205:	learn: 0.2342720	total: 845ms	remaining: 3.25s
# 206:	learn: 0.2337753	total: 849ms	remaining: 3.25s
# 207:	learn: 0.2327957	total: 854ms	remaining: 3.25s
# 208:	learn: 0.2316173	total: 858ms	remaining: 3.25s
# 209:	learn: 0.2312332	total: 862ms	remaining: 3.24s
# 210:	learn: 0.2306886	total: 866ms	remaining: 3.24s
# 211:	learn: 0.2298818	total: 871ms	remaining: 3.24s
# 212:	learn: 0.2286156	total: 876ms	remaining: 3.23s
# 213:	learn: 0.2277584	total: 879ms	remaining: 3.23s
# 214:	learn: 0.2273535	total: 883ms	remaining: 3.22s
# 215:	learn: 0.2262860	total: 887ms	remaining: 3.22s
# 216:	learn: 0.2256441	total: 891ms	remaining: 3.21s
# 217:	learn: 0.2253794	total: 895ms	remaining: 3.21s
# 218:	learn: 0.2247772	total: 899ms	remaining: 3.21s
# 219:	learn: 0.2240358	total: 903ms	remaining: 3.2s
# 220:	learn: 0.2234839	total: 907ms	remaining: 3.19s
# 221:	learn: 0.2225620	total: 911ms	remaining: 3.19s
# 222:	learn: 0.2220235	total: 915ms	remaining: 3.19s
# 223:	learn: 0.2210733	total: 918ms	remaining: 3.18s
# 224:	learn: 0.2210223	total: 923ms	remaining: 3.18s
# 225:	learn: 0.2209086	total: 927ms	remaining: 3.17s
# 226:	learn: 0.2207795	total: 931ms	remaining: 3.17s
# 227:	learn: 0.2203322	total: 935ms	remaining: 3.16s
# 228:	learn: 0.2199864	total: 939ms	remaining: 3.16s
# 229:	learn: 0.2196187	total: 943ms	remaining: 3.15s
# 230:	learn: 0.2185479	total: 946ms	remaining: 3.15s
# 231:	learn: 0.2175833	total: 950ms	remaining: 3.15s
# 232:	learn: 0.2168524	total: 955ms	remaining: 3.14s
# 233:	learn: 0.2160753	total: 959ms	remaining: 3.14s
# 234:	learn: 0.2155040	total: 964ms	remaining: 3.14s
# 235:	learn: 0.2153019	total: 968ms	remaining: 3.13s
# 236:	learn: 0.2147683	total: 973ms	remaining: 3.13s
# 237:	learn: 0.2146508	total: 978ms	remaining: 3.13s
# 238:	learn: 0.2139362	total: 982ms	remaining: 3.13s
# 239:	learn: 0.2133251	total: 986ms	remaining: 3.12s
# 240:	learn: 0.2125841	total: 990ms	remaining: 3.12s
# 241:	learn: 0.2119161	total: 994ms	remaining: 3.11s
# 242:	learn: 0.2117300	total: 998ms	remaining: 3.11s
# 243:	learn: 0.2112861	total: 1s	remaining: 3.1s
# 244:	learn: 0.2109638	total: 1s	remaining: 3.1s
# 245:	learn: 0.2108478	total: 1.01s	remaining: 3.09s
# 246:	learn: 0.2101150	total: 1.01s	remaining: 3.09s
# 247:	learn: 0.2092221	total: 1.02s	remaining: 3.08s
# 248:	learn: 0.2088303	total: 1.02s	remaining: 3.08s
# 249:	learn: 0.2080980	total: 1.02s	remaining: 3.07s
# 250:	learn: 0.2073933	total: 1.03s	remaining: 3.07s
# 251:	learn: 0.2067048	total: 1.03s	remaining: 3.06s
# 252:	learn: 0.2056142	total: 1.03s	remaining: 3.06s
# 253:	learn: 0.2050820	total: 1.04s	remaining: 3.05s
# 254:	learn: 0.2047999	total: 1.04s	remaining: 3.05s
# 255:	learn: 0.2042355	total: 1.05s	remaining: 3.04s
# 256:	learn: 0.2030677	total: 1.05s	remaining: 3.04s
# 257:	learn: 0.2028410	total: 1.05s	remaining: 3.03s
# 258:	learn: 0.2021985	total: 1.06s	remaining: 3.02s
# 259:	learn: 0.2018967	total: 1.06s	remaining: 3.02s
# 260:	learn: 0.2011730	total: 1.06s	remaining: 3.01s
# 261:	learn: 0.2008900	total: 1.07s	remaining: 3.01s
# 262:	learn: 0.2004090	total: 1.07s	remaining: 3s
# 263:	learn: 0.2000749	total: 1.07s	remaining: 3s
# 264:	learn: 0.1997014	total: 1.08s	remaining: 2.99s
# 265:	learn: 0.1992889	total: 1.08s	remaining: 2.99s
# 266:	learn: 0.1990640	total: 1.09s	remaining: 2.98s
# 267:	learn: 0.1981991	total: 1.09s	remaining: 2.98s
# 268:	learn: 0.1977812	total: 1.09s	remaining: 2.97s
# 269:	learn: 0.1972650	total: 1.1s	remaining: 2.97s
# 270:	learn: 0.1969458	total: 1.1s	remaining: 2.96s
# 271:	learn: 0.1963947	total: 1.1s	remaining: 2.96s
# 272:	learn: 0.1960029	total: 1.11s	remaining: 2.95s
# 273:	learn: 0.1956367	total: 1.11s	remaining: 2.95s
# 274:	learn: 0.1949667	total: 1.12s	remaining: 2.95s
# 275:	learn: 0.1945795	total: 1.12s	remaining: 2.94s
# 276:	learn: 0.1938285	total: 1.13s	remaining: 2.94s
# 277:	learn: 0.1933462	total: 1.13s	remaining: 2.93s
# 278:	learn: 0.1924595	total: 1.13s	remaining: 2.93s
# 279:	learn: 0.1913488	total: 1.14s	remaining: 2.92s
# 280:	learn: 0.1906926	total: 1.14s	remaining: 2.92s
# 281:	learn: 0.1899435	total: 1.14s	remaining: 2.91s
# 282:	learn: 0.1892750	total: 1.15s	remaining: 2.91s
# 283:	learn: 0.1884991	total: 1.15s	remaining: 2.9s
# 284:	learn: 0.1882499	total: 1.15s	remaining: 2.9s
# 285:	learn: 0.1877207	total: 1.16s	remaining: 2.89s
# 286:	learn: 0.1871939	total: 1.16s	remaining: 2.89s
# 287:	learn: 0.1867257	total: 1.17s	remaining: 2.88s
# 288:	learn: 0.1862143	total: 1.17s	remaining: 2.88s
# 289:	learn: 0.1860476	total: 1.18s	remaining: 2.88s
# 290:	learn: 0.1858575	total: 1.18s	remaining: 2.87s
# 291:	learn: 0.1855626	total: 1.18s	remaining: 2.87s
# 292:	learn: 0.1847757	total: 1.19s	remaining: 2.86s
# 293:	learn: 0.1840575	total: 1.19s	remaining: 2.86s
# 294:	learn: 0.1837589	total: 1.19s	remaining: 2.85s
# 295:	learn: 0.1832995	total: 1.2s	remaining: 2.85s
# 296:	learn: 0.1828666	total: 1.2s	remaining: 2.85s
# 297:	learn: 0.1822980	total: 1.21s	remaining: 2.84s
# 298:	learn: 0.1818352	total: 1.21s	remaining: 2.83s
# 299:	learn: 0.1814613	total: 1.21s	remaining: 2.83s
# 300:	learn: 0.1810572	total: 1.22s	remaining: 2.83s
# 301:	learn: 0.1805593	total: 1.22s	remaining: 2.82s
# 302:	learn: 0.1799065	total: 1.22s	remaining: 2.82s
# 303:	learn: 0.1794273	total: 1.23s	remaining: 2.81s
# 304:	learn: 0.1788937	total: 1.23s	remaining: 2.81s
# 305:	learn: 0.1781362	total: 1.24s	remaining: 2.8s
# 306:	learn: 0.1773375	total: 1.24s	remaining: 2.8s
# 307:	learn: 0.1768716	total: 1.24s	remaining: 2.79s
# 308:	learn: 0.1766236	total: 1.25s	remaining: 2.79s
# 309:	learn: 0.1763629	total: 1.25s	remaining: 2.79s
# 310:	learn: 0.1757270	total: 1.26s	remaining: 2.78s
# 311:	learn: 0.1752446	total: 1.26s	remaining: 2.78s
# 312:	learn: 0.1746033	total: 1.26s	remaining: 2.77s
# 313:	learn: 0.1737944	total: 1.27s	remaining: 2.77s
# 314:	learn: 0.1730284	total: 1.27s	remaining: 2.77s
# 315:	learn: 0.1724448	total: 1.27s	remaining: 2.76s
# 316:	learn: 0.1719782	total: 1.28s	remaining: 2.76s
# 317:	learn: 0.1717006	total: 1.28s	remaining: 2.75s
# 318:	learn: 0.1714266	total: 1.29s	remaining: 2.75s
# 319:	learn: 0.1708419	total: 1.29s	remaining: 2.74s
# 320:	learn: 0.1702894	total: 1.29s	remaining: 2.74s
# 321:	learn: 0.1697650	total: 1.3s	remaining: 2.74s
# 322:	learn: 0.1696806	total: 1.3s	remaining: 2.73s
# 323:	learn: 0.1695072	total: 1.31s	remaining: 2.73s
# 324:	learn: 0.1691014	total: 1.31s	remaining: 2.73s
# 325:	learn: 0.1686859	total: 1.31s	remaining: 2.72s
# 326:	learn: 0.1686314	total: 1.32s	remaining: 2.72s
# 327:	learn: 0.1682228	total: 1.32s	remaining: 2.71s
# 328:	learn: 0.1676096	total: 1.33s	remaining: 2.71s
# 329:	learn: 0.1670982	total: 1.33s	remaining: 2.71s
# 330:	learn: 0.1665498	total: 1.34s	remaining: 2.7s
# 331:	learn: 0.1662797	total: 1.34s	remaining: 2.7s
# 332:	learn: 0.1657838	total: 1.34s	remaining: 2.69s
# 333:	learn: 0.1653401	total: 1.35s	remaining: 2.69s
# 334:	learn: 0.1649264	total: 1.35s	remaining: 2.68s
# 335:	learn: 0.1639505	total: 1.36s	remaining: 2.68s
# 336:	learn: 0.1635271	total: 1.36s	remaining: 2.68s
# 337:	learn: 0.1630843	total: 1.36s	remaining: 2.67s
# 338:	learn: 0.1625562	total: 1.37s	remaining: 2.67s
# 339:	learn: 0.1622885	total: 1.37s	remaining: 2.67s
# 340:	learn: 0.1620198	total: 1.38s	remaining: 2.67s
# 341:	learn: 0.1615960	total: 1.39s	remaining: 2.67s
# 342:	learn: 0.1610777	total: 1.39s	remaining: 2.66s
# 343:	learn: 0.1603451	total: 1.39s	remaining: 2.66s
# 344:	learn: 0.1600029	total: 1.4s	remaining: 2.65s
# 345:	learn: 0.1597714	total: 1.4s	remaining: 2.65s
# 346:	learn: 0.1593784	total: 1.41s	remaining: 2.65s
# 347:	learn: 0.1590799	total: 1.41s	remaining: 2.64s
# 348:	learn: 0.1582371	total: 1.41s	remaining: 2.64s
# 349:	learn: 0.1579377	total: 1.42s	remaining: 2.63s
# 350:	learn: 0.1575666	total: 1.42s	remaining: 2.63s
# 351:	learn: 0.1572028	total: 1.43s	remaining: 2.62s
# 352:	learn: 0.1567732	total: 1.43s	remaining: 2.62s
# 353:	learn: 0.1566008	total: 1.43s	remaining: 2.61s
# 354:	learn: 0.1564444	total: 1.44s	remaining: 2.61s
# 355:	learn: 0.1560580	total: 1.44s	remaining: 2.6s
# 356:	learn: 0.1557368	total: 1.44s	remaining: 2.6s
# 357:	learn: 0.1553175	total: 1.45s	remaining: 2.6s
# 358:	learn: 0.1546495	total: 1.45s	remaining: 2.59s
# 359:	learn: 0.1542692	total: 1.46s	remaining: 2.59s
# 360:	learn: 0.1537764	total: 1.46s	remaining: 2.58s
# 361:	learn: 0.1534990	total: 1.46s	remaining: 2.58s
# 362:	learn: 0.1530731	total: 1.47s	remaining: 2.58s
# 363:	learn: 0.1527061	total: 1.47s	remaining: 2.57s
# 364:	learn: 0.1524622	total: 1.47s	remaining: 2.56s
# 365:	learn: 0.1520909	total: 1.48s	remaining: 2.56s
# 366:	learn: 0.1515453	total: 1.48s	remaining: 2.56s
# 367:	learn: 0.1511557	total: 1.49s	remaining: 2.55s
# 368:	learn: 0.1505576	total: 1.49s	remaining: 2.55s
# 369:	learn: 0.1503663	total: 1.49s	remaining: 2.54s
# 370:	learn: 0.1497010	total: 1.5s	remaining: 2.54s
# 371:	learn: 0.1494050	total: 1.5s	remaining: 2.53s
# 372:	learn: 0.1490612	total: 1.5s	remaining: 2.53s
# 373:	learn: 0.1486400	total: 1.51s	remaining: 2.52s
# 374:	learn: 0.1483988	total: 1.51s	remaining: 2.52s
# 375:	learn: 0.1482093	total: 1.51s	remaining: 2.52s
# 376:	learn: 0.1478147	total: 1.52s	remaining: 2.51s
# 377:	learn: 0.1476980	total: 1.52s	remaining: 2.5s
# 378:	learn: 0.1472089	total: 1.53s	remaining: 2.5s
# 379:	learn: 0.1468077	total: 1.53s	remaining: 2.5s
# 380:	learn: 0.1462024	total: 1.53s	remaining: 2.49s
# 381:	learn: 0.1458724	total: 1.54s	remaining: 2.49s
# 382:	learn: 0.1454284	total: 1.54s	remaining: 2.48s
# 383:	learn: 0.1450317	total: 1.54s	remaining: 2.48s
# 384:	learn: 0.1445896	total: 1.55s	remaining: 2.48s
# 385:	learn: 0.1444076	total: 1.55s	remaining: 2.47s
# 386:	learn: 0.1439490	total: 1.56s	remaining: 2.47s
# 387:	learn: 0.1435927	total: 1.56s	remaining: 2.46s
# 388:	learn: 0.1430955	total: 1.57s	remaining: 2.46s
# 389:	learn: 0.1425692	total: 1.57s	remaining: 2.46s
# 390:	learn: 0.1422614	total: 1.58s	remaining: 2.46s
# 391:	learn: 0.1418756	total: 1.58s	remaining: 2.45s
# 392:	learn: 0.1414752	total: 1.59s	remaining: 2.45s
# 393:	learn: 0.1411786	total: 1.59s	remaining: 2.45s
# 394:	learn: 0.1409433	total: 1.59s	remaining: 2.44s
# 395:	learn: 0.1408093	total: 1.6s	remaining: 2.44s
# 396:	learn: 0.1404497	total: 1.6s	remaining: 2.44s
# 397:	learn: 0.1400859	total: 1.61s	remaining: 2.43s
# 398:	learn: 0.1395975	total: 1.61s	remaining: 2.43s
# 399:	learn: 0.1392154	total: 1.61s	remaining: 2.42s
# 400:	learn: 0.1387515	total: 1.62s	remaining: 2.42s
# 401:	learn: 0.1385647	total: 1.62s	remaining: 2.42s
# 402:	learn: 0.1383594	total: 1.63s	remaining: 2.41s
# 403:	learn: 0.1379032	total: 1.63s	remaining: 2.41s
# 404:	learn: 0.1374346	total: 1.64s	remaining: 2.4s
# 405:	learn: 0.1371454	total: 1.64s	remaining: 2.4s
# 406:	learn: 0.1369328	total: 1.64s	remaining: 2.39s
# 407:	learn: 0.1365976	total: 1.65s	remaining: 2.39s
# 408:	learn: 0.1361413	total: 1.65s	remaining: 2.39s
# 409:	learn: 0.1357186	total: 1.66s	remaining: 2.38s
# 410:	learn: 0.1353959	total: 1.66s	remaining: 2.38s
# 411:	learn: 0.1350337	total: 1.67s	remaining: 2.38s
# 412:	learn: 0.1346442	total: 1.67s	remaining: 2.37s
# 413:	learn: 0.1341953	total: 1.67s	remaining: 2.37s
# 414:	learn: 0.1339519	total: 1.68s	remaining: 2.36s
# 415:	learn: 0.1336823	total: 1.68s	remaining: 2.36s
# 416:	learn: 0.1334807	total: 1.69s	remaining: 2.36s
# 417:	learn: 0.1332870	total: 1.69s	remaining: 2.35s
# 418:	learn: 0.1327823	total: 1.69s	remaining: 2.35s
# 419:	learn: 0.1325798	total: 1.7s	remaining: 2.34s
# 420:	learn: 0.1322418	total: 1.7s	remaining: 2.34s
# 421:	learn: 0.1318809	total: 1.71s	remaining: 2.34s
# 422:	learn: 0.1317726	total: 1.72s	remaining: 2.34s
# 423:	learn: 0.1315704	total: 1.72s	remaining: 2.33s
# 424:	learn: 0.1312392	total: 1.72s	remaining: 2.33s
# 425:	learn: 0.1310788	total: 1.73s	remaining: 2.33s
# 426:	learn: 0.1306258	total: 1.73s	remaining: 2.32s
# 427:	learn: 0.1303270	total: 1.73s	remaining: 2.32s
# 428:	learn: 0.1299708	total: 1.74s	remaining: 2.31s
# 429:	learn: 0.1298674	total: 1.74s	remaining: 2.31s
# 430:	learn: 0.1295532	total: 1.75s	remaining: 2.31s
# 431:	learn: 0.1288803	total: 1.75s	remaining: 2.3s
# 432:	learn: 0.1284990	total: 1.75s	remaining: 2.3s
# 433:	learn: 0.1282159	total: 1.76s	remaining: 2.29s
# 434:	learn: 0.1278680	total: 1.81s	remaining: 2.35s
# 435:	learn: 0.1276827	total: 1.81s	remaining: 2.35s
# 436:	learn: 0.1273988	total: 1.82s	remaining: 2.35s
# 437:	learn: 0.1269491	total: 1.83s	remaining: 2.34s
# 438:	learn: 0.1266628	total: 1.83s	remaining: 2.34s
# 439:	learn: 0.1263566	total: 1.83s	remaining: 2.33s
# 440:	learn: 0.1262184	total: 1.84s	remaining: 2.33s
# 441:	learn: 0.1260297	total: 1.84s	remaining: 2.33s
# 442:	learn: 0.1257261	total: 1.85s	remaining: 2.32s
# 443:	learn: 0.1254186	total: 1.85s	remaining: 2.32s
# 444:	learn: 0.1251688	total: 1.85s	remaining: 2.31s
# 445:	learn: 0.1249231	total: 1.86s	remaining: 2.31s
# 446:	learn: 0.1246428	total: 1.86s	remaining: 2.3s
# 447:	learn: 0.1244222	total: 1.87s	remaining: 2.3s
# 448:	learn: 0.1238696	total: 1.87s	remaining: 2.3s
# 449:	learn: 0.1234469	total: 1.88s	remaining: 2.29s
# 450:	learn: 0.1232305	total: 1.88s	remaining: 2.29s
# 451:	learn: 0.1229027	total: 1.88s	remaining: 2.28s
# 452:	learn: 0.1225384	total: 1.89s	remaining: 2.28s
# 453:	learn: 0.1220666	total: 1.89s	remaining: 2.27s
# 454:	learn: 0.1216502	total: 1.89s	remaining: 2.27s
# 455:	learn: 0.1212447	total: 1.9s	remaining: 2.26s
# 456:	learn: 0.1211476	total: 1.9s	remaining: 2.26s
# 457:	learn: 0.1208555	total: 1.91s	remaining: 2.25s
# 458:	learn: 0.1204714	total: 1.91s	remaining: 2.25s
# 459:	learn: 0.1201053	total: 1.91s	remaining: 2.25s
# 460:	learn: 0.1198628	total: 1.92s	remaining: 2.24s
# 461:	learn: 0.1196514	total: 1.92s	remaining: 2.24s
# 462:	learn: 0.1194743	total: 1.92s	remaining: 2.23s
# 463:	learn: 0.1193208	total: 1.93s	remaining: 2.23s
# 464:	learn: 0.1191561	total: 1.93s	remaining: 2.22s
# 465:	learn: 0.1190552	total: 1.94s	remaining: 2.22s
# 466:	learn: 0.1188920	total: 1.94s	remaining: 2.21s
# 467:	learn: 0.1187699	total: 1.94s	remaining: 2.21s
# 468:	learn: 0.1183869	total: 1.95s	remaining: 2.21s
# 469:	learn: 0.1182508	total: 1.95s	remaining: 2.2s
# 470:	learn: 0.1179105	total: 1.96s	remaining: 2.2s
# 471:	learn: 0.1176520	total: 1.96s	remaining: 2.19s
# 472:	learn: 0.1174189	total: 1.97s	remaining: 2.19s
# 473:	learn: 0.1170960	total: 1.97s	remaining: 2.19s
# 474:	learn: 0.1169506	total: 1.97s	remaining: 2.18s
# 475:	learn: 0.1166808	total: 1.98s	remaining: 2.18s
# 476:	learn: 0.1162676	total: 1.98s	remaining: 2.17s
# 477:	learn: 0.1160563	total: 1.99s	remaining: 2.17s
# 478:	learn: 0.1158518	total: 1.99s	remaining: 2.17s
# 479:	learn: 0.1154228	total: 1.99s	remaining: 2.16s
# 480:	learn: 0.1152517	total: 2s	remaining: 2.16s
# 481:	learn: 0.1148950	total: 2s	remaining: 2.15s
# 482:	learn: 0.1144795	total: 2.01s	remaining: 2.15s
# 483:	learn: 0.1142872	total: 2.01s	remaining: 2.14s
# 484:	learn: 0.1140573	total: 2.02s	remaining: 2.14s
# 485:	learn: 0.1137553	total: 2.02s	remaining: 2.13s
# 486:	learn: 0.1135425	total: 2.02s	remaining: 2.13s
# 487:	learn: 0.1133013	total: 2.03s	remaining: 2.13s
# 488:	learn: 0.1130717	total: 2.03s	remaining: 2.12s
# 489:	learn: 0.1127104	total: 2.04s	remaining: 2.12s
# 490:	learn: 0.1125008	total: 2.04s	remaining: 2.11s
# 491:	learn: 0.1122393	total: 2.04s	remaining: 2.11s
# 492:	learn: 0.1119313	total: 2.05s	remaining: 2.11s
# 493:	learn: 0.1115317	total: 2.05s	remaining: 2.1s
# 494:	learn: 0.1114490	total: 2.06s	remaining: 2.1s
# 495:	learn: 0.1109055	total: 2.06s	remaining: 2.09s
# 496:	learn: 0.1107725	total: 2.06s	remaining: 2.09s
# 497:	learn: 0.1106306	total: 2.07s	remaining: 2.08s
# 498:	learn: 0.1105124	total: 2.07s	remaining: 2.08s
# 499:	learn: 0.1102980	total: 2.07s	remaining: 2.07s
# 500:	learn: 0.1100986	total: 2.08s	remaining: 2.07s
# 501:	learn: 0.1098843	total: 2.08s	remaining: 2.06s
# 502:	learn: 0.1097811	total: 2.09s	remaining: 2.06s
# 503:	learn: 0.1096547	total: 2.09s	remaining: 2.06s
# 504:	learn: 0.1093987	total: 2.09s	remaining: 2.05s
# 505:	learn: 0.1091240	total: 2.1s	remaining: 2.05s
# 506:	learn: 0.1087133	total: 2.1s	remaining: 2.04s
# 507:	learn: 0.1085131	total: 2.1s	remaining: 2.04s
# 508:	learn: 0.1082999	total: 2.11s	remaining: 2.03s
# 509:	learn: 0.1078569	total: 2.11s	remaining: 2.03s
# 510:	learn: 0.1073356	total: 2.12s	remaining: 2.02s
# 511:	learn: 0.1070528	total: 2.12s	remaining: 2.02s
# 512:	learn: 0.1067049	total: 2.12s	remaining: 2.02s
# 513:	learn: 0.1065026	total: 2.13s	remaining: 2.01s
# 514:	learn: 0.1063236	total: 2.13s	remaining: 2.01s
# 515:	learn: 0.1060601	total: 2.13s	remaining: 2s
# 516:	learn: 0.1057806	total: 2.14s	remaining: 2s
# 517:	learn: 0.1054392	total: 2.14s	remaining: 1.99s
# 518:	learn: 0.1049894	total: 2.15s	remaining: 1.99s
# 519:	learn: 0.1046860	total: 2.15s	remaining: 1.99s
# 520:	learn: 0.1045070	total: 2.15s	remaining: 1.98s
# 521:	learn: 0.1044069	total: 2.16s	remaining: 1.98s
# 522:	learn: 0.1040668	total: 2.16s	remaining: 1.97s
# 523:	learn: 0.1038391	total: 2.17s	remaining: 1.97s
# 524:	learn: 0.1034352	total: 2.17s	remaining: 1.97s
# 525:	learn: 0.1032078	total: 2.18s	remaining: 1.96s
# 526:	learn: 0.1028041	total: 2.18s	remaining: 1.96s
# 527:	learn: 0.1025000	total: 2.19s	remaining: 1.95s
# 528:	learn: 0.1023907	total: 2.19s	remaining: 1.95s
# 529:	learn: 0.1021000	total: 2.19s	remaining: 1.95s
# 530:	learn: 0.1019505	total: 2.2s	remaining: 1.94s
# 531:	learn: 0.1016996	total: 2.2s	remaining: 1.94s
# 532:	learn: 0.1014595	total: 2.21s	remaining: 1.93s
# 533:	learn: 0.1011616	total: 2.21s	remaining: 1.93s
# 534:	learn: 0.1009615	total: 2.21s	remaining: 1.92s
# 535:	learn: 0.1007710	total: 2.22s	remaining: 1.92s
# 536:	learn: 0.1005826	total: 2.22s	remaining: 1.92s
# 537:	learn: 0.1003377	total: 2.23s	remaining: 1.91s
# 538:	learn: 0.1001964	total: 2.23s	remaining: 1.91s
# 539:	learn: 0.0999381	total: 2.23s	remaining: 1.9s
# 540:	learn: 0.0995191	total: 2.24s	remaining: 1.9s
# 541:	learn: 0.0993136	total: 2.24s	remaining: 1.89s
# 542:	learn: 0.0990943	total: 2.25s	remaining: 1.89s
# 543:	learn: 0.0988429	total: 2.25s	remaining: 1.89s
# 544:	learn: 0.0985825	total: 2.25s	remaining: 1.88s
# 545:	learn: 0.0982837	total: 2.26s	remaining: 1.88s
# 546:	learn: 0.0981070	total: 2.26s	remaining: 1.87s
# 547:	learn: 0.0978528	total: 2.26s	remaining: 1.87s
# 548:	learn: 0.0976257	total: 2.27s	remaining: 1.86s
# 549:	learn: 0.0970837	total: 2.27s	remaining: 1.86s
# 550:	learn: 0.0969037	total: 2.27s	remaining: 1.85s
# 551:	learn: 0.0964944	total: 2.28s	remaining: 1.85s
# 552:	learn: 0.0963769	total: 2.28s	remaining: 1.84s
# 553:	learn: 0.0962265	total: 2.29s	remaining: 1.84s
# 554:	learn: 0.0959936	total: 2.29s	remaining: 1.84s
# 555:	learn: 0.0956969	total: 2.29s	remaining: 1.83s
# 556:	learn: 0.0954807	total: 2.3s	remaining: 1.83s
# 557:	learn: 0.0953983	total: 2.3s	remaining: 1.82s
# 558:	learn: 0.0951019	total: 2.31s	remaining: 1.82s
# 559:	learn: 0.0949123	total: 2.31s	remaining: 1.81s
# 560:	learn: 0.0946585	total: 2.31s	remaining: 1.81s
# 561:	learn: 0.0945317	total: 2.32s	remaining: 1.81s
# 562:	learn: 0.0942524	total: 2.32s	remaining: 1.8s
# 563:	learn: 0.0940771	total: 2.32s	remaining: 1.8s
# 564:	learn: 0.0939402	total: 2.33s	remaining: 1.79s
# 565:	learn: 0.0938258	total: 2.33s	remaining: 1.79s
# 566:	learn: 0.0936767	total: 2.33s	remaining: 1.78s
# 567:	learn: 0.0933270	total: 2.34s	remaining: 1.78s
# 568:	learn: 0.0930739	total: 2.34s	remaining: 1.77s
# 569:	learn: 0.0927922	total: 2.35s	remaining: 1.77s
# 570:	learn: 0.0926197	total: 2.35s	remaining: 1.77s
# 571:	learn: 0.0925334	total: 2.36s	remaining: 1.76s
# 572:	learn: 0.0923963	total: 2.36s	remaining: 1.76s
# 573:	learn: 0.0921357	total: 2.37s	remaining: 1.75s
# 574:	learn: 0.0919893	total: 2.37s	remaining: 1.75s
# 575:	learn: 0.0917828	total: 2.37s	remaining: 1.75s
# 576:	learn: 0.0915216	total: 2.42s	remaining: 1.77s
# 577:	learn: 0.0913221	total: 2.42s	remaining: 1.77s
# 578:	learn: 0.0911333	total: 2.43s	remaining: 1.77s
# 579:	learn: 0.0908583	total: 2.44s	remaining: 1.76s
# 580:	learn: 0.0907035	total: 2.44s	remaining: 1.76s
# 581:	learn: 0.0905544	total: 2.44s	remaining: 1.75s
# 582:	learn: 0.0902918	total: 2.45s	remaining: 1.75s
# 583:	learn: 0.0901118	total: 2.45s	remaining: 1.75s
# 584:	learn: 0.0898916	total: 2.46s	remaining: 1.74s
# 585:	learn: 0.0897775	total: 2.46s	remaining: 1.74s
# 586:	learn: 0.0896829	total: 2.46s	remaining: 1.73s
# 587:	learn: 0.0895016	total: 2.47s	remaining: 1.73s
# 588:	learn: 0.0893000	total: 2.47s	remaining: 1.73s
# 589:	learn: 0.0891115	total: 2.48s	remaining: 1.72s
# 590:	learn: 0.0889520	total: 2.48s	remaining: 1.72s
# 591:	learn: 0.0887714	total: 2.49s	remaining: 1.71s
# 592:	learn: 0.0886938	total: 2.49s	remaining: 1.71s
# 593:	learn: 0.0885350	total: 2.5s	remaining: 1.71s
# 594:	learn: 0.0882768	total: 2.5s	remaining: 1.7s
# 595:	learn: 0.0880360	total: 2.5s	remaining: 1.7s
# 596:	learn: 0.0878599	total: 2.51s	remaining: 1.69s
# 597:	learn: 0.0877108	total: 2.52s	remaining: 1.69s
# 598:	learn: 0.0874900	total: 2.52s	remaining: 1.69s
# 599:	learn: 0.0872312	total: 2.52s	remaining: 1.68s
# 600:	learn: 0.0869164	total: 2.53s	remaining: 1.68s
# 601:	learn: 0.0866440	total: 2.53s	remaining: 1.68s
# 602:	learn: 0.0865108	total: 2.54s	remaining: 1.67s
# 603:	learn: 0.0864532	total: 2.54s	remaining: 1.67s
# 604:	learn: 0.0861326	total: 2.55s	remaining: 1.66s
# 605:	learn: 0.0860069	total: 2.55s	remaining: 1.66s
# 606:	learn: 0.0858706	total: 2.56s	remaining: 1.65s
# 607:	learn: 0.0858317	total: 2.56s	remaining: 1.65s
# 608:	learn: 0.0856855	total: 2.56s	remaining: 1.65s
# 609:	learn: 0.0855727	total: 2.57s	remaining: 1.64s
# 610:	learn: 0.0853866	total: 2.57s	remaining: 1.64s
# 611:	learn: 0.0852963	total: 2.58s	remaining: 1.63s
# 612:	learn: 0.0851539	total: 2.58s	remaining: 1.63s
# 613:	learn: 0.0849133	total: 2.58s	remaining: 1.63s
# 614:	learn: 0.0847344	total: 2.59s	remaining: 1.62s
# 615:	learn: 0.0845929	total: 2.59s	remaining: 1.62s
# 616:	learn: 0.0844028	total: 2.6s	remaining: 1.61s
# 617:	learn: 0.0841488	total: 2.6s	remaining: 1.61s
# 618:	learn: 0.0839578	total: 2.6s	remaining: 1.6s
# 619:	learn: 0.0837549	total: 2.61s	remaining: 1.6s
# 620:	learn: 0.0836860	total: 2.61s	remaining: 1.59s
# 621:	learn: 0.0835612	total: 2.62s	remaining: 1.59s
# 622:	learn: 0.0833596	total: 2.62s	remaining: 1.59s
# 623:	learn: 0.0831555	total: 2.63s	remaining: 1.58s
# 624:	learn: 0.0830496	total: 2.63s	remaining: 1.58s
# 625:	learn: 0.0829450	total: 2.63s	remaining: 1.57s
# 626:	learn: 0.0828031	total: 2.64s	remaining: 1.57s
# 627:	learn: 0.0826923	total: 2.64s	remaining: 1.56s
# 628:	learn: 0.0825524	total: 2.65s	remaining: 1.56s
# 629:	learn: 0.0823901	total: 2.65s	remaining: 1.56s
# 630:	learn: 0.0822603	total: 2.65s	remaining: 1.55s
# 631:	learn: 0.0821381	total: 2.66s	remaining: 1.55s
# 632:	learn: 0.0820737	total: 2.66s	remaining: 1.54s
# 633:	learn: 0.0818595	total: 2.67s	remaining: 1.54s
# 634:	learn: 0.0816646	total: 2.67s	remaining: 1.53s
# 635:	learn: 0.0813958	total: 2.67s	remaining: 1.53s
# 636:	learn: 0.0812417	total: 2.68s	remaining: 1.52s
# 637:	learn: 0.0811407	total: 2.68s	remaining: 1.52s
# 638:	learn: 0.0809605	total: 2.68s	remaining: 1.52s
# 639:	learn: 0.0806815	total: 2.69s	remaining: 1.51s
# 640:	learn: 0.0805912	total: 2.69s	remaining: 1.51s
# 641:	learn: 0.0802638	total: 2.7s	remaining: 1.5s
# 642:	learn: 0.0800489	total: 2.7s	remaining: 1.5s
# 643:	learn: 0.0799359	total: 2.7s	remaining: 1.49s
# 644:	learn: 0.0798816	total: 2.71s	remaining: 1.49s
# 645:	learn: 0.0797619	total: 2.71s	remaining: 1.49s
# 646:	learn: 0.0796377	total: 2.71s	remaining: 1.48s
# 647:	learn: 0.0793853	total: 2.72s	remaining: 1.48s
# 648:	learn: 0.0792370	total: 2.72s	remaining: 1.47s
# 649:	learn: 0.0790414	total: 2.73s	remaining: 1.47s
# 650:	learn: 0.0789404	total: 2.73s	remaining: 1.46s
# 651:	learn: 0.0788144	total: 2.73s	remaining: 1.46s
# 652:	learn: 0.0786719	total: 2.74s	remaining: 1.45s
# 653:	learn: 0.0785262	total: 2.74s	remaining: 1.45s
# 654:	learn: 0.0783561	total: 2.75s	remaining: 1.45s
# 655:	learn: 0.0783022	total: 2.75s	remaining: 1.44s
# 656:	learn: 0.0781277	total: 2.75s	remaining: 1.44s
# 657:	learn: 0.0779258	total: 2.76s	remaining: 1.43s
# 658:	learn: 0.0778780	total: 2.76s	remaining: 1.43s
# 659:	learn: 0.0776867	total: 2.77s	remaining: 1.43s
# 660:	learn: 0.0774135	total: 2.77s	remaining: 1.42s
# 661:	learn: 0.0772475	total: 2.77s	remaining: 1.42s
# 662:	learn: 0.0771246	total: 2.78s	remaining: 1.41s
# 663:	learn: 0.0768441	total: 2.78s	remaining: 1.41s
# 664:	learn: 0.0767975	total: 2.79s	remaining: 1.41s
# 665:	learn: 0.0766161	total: 2.79s	remaining: 1.4s
# 666:	learn: 0.0763900	total: 2.8s	remaining: 1.4s
# 667:	learn: 0.0761807	total: 2.8s	remaining: 1.39s
# 668:	learn: 0.0761050	total: 2.8s	remaining: 1.39s
# 669:	learn: 0.0760252	total: 2.81s	remaining: 1.38s
# 670:	learn: 0.0758960	total: 2.81s	remaining: 1.38s
# 671:	learn: 0.0757931	total: 2.82s	remaining: 1.37s
# 672:	learn: 0.0757065	total: 2.82s	remaining: 1.37s
# 673:	learn: 0.0755252	total: 2.82s	remaining: 1.36s
# 674:	learn: 0.0754536	total: 2.83s	remaining: 1.36s
# 675:	learn: 0.0752603	total: 2.83s	remaining: 1.36s
# 676:	learn: 0.0749560	total: 2.83s	remaining: 1.35s
# 677:	learn: 0.0749018	total: 2.84s	remaining: 1.35s
# 678:	learn: 0.0747917	total: 2.84s	remaining: 1.34s
# 679:	learn: 0.0746157	total: 2.85s	remaining: 1.34s
# 680:	learn: 0.0744998	total: 2.85s	remaining: 1.33s
# 681:	learn: 0.0743689	total: 2.85s	remaining: 1.33s
# 682:	learn: 0.0741550	total: 2.86s	remaining: 1.33s
# 683:	learn: 0.0739950	total: 2.86s	remaining: 1.32s
# 684:	learn: 0.0737152	total: 2.87s	remaining: 1.32s
# 685:	learn: 0.0735856	total: 2.87s	remaining: 1.31s
# 686:	learn: 0.0735029	total: 2.87s	remaining: 1.31s
# 687:	learn: 0.0733614	total: 2.88s	remaining: 1.3s
# 688:	learn: 0.0732623	total: 2.88s	remaining: 1.3s
# 689:	learn: 0.0730683	total: 2.89s	remaining: 1.3s
# 690:	learn: 0.0728742	total: 2.89s	remaining: 1.29s
# 691:	learn: 0.0727783	total: 2.9s	remaining: 1.29s
# 692:	learn: 0.0727057	total: 2.9s	remaining: 1.28s
# 693:	learn: 0.0725114	total: 2.9s	remaining: 1.28s
# 694:	learn: 0.0724317	total: 2.91s	remaining: 1.27s
# 695:	learn: 0.0723815	total: 2.91s	remaining: 1.27s
# 696:	learn: 0.0722190	total: 2.91s	remaining: 1.27s
# 697:	learn: 0.0720550	total: 2.92s	remaining: 1.26s
# 698:	learn: 0.0719778	total: 2.92s	remaining: 1.26s
# 699:	learn: 0.0718131	total: 2.93s	remaining: 1.25s
# 700:	learn: 0.0715556	total: 2.93s	remaining: 1.25s
# 701:	learn: 0.0714154	total: 2.93s	remaining: 1.25s
# 702:	learn: 0.0712913	total: 2.94s	remaining: 1.24s
# 703:	learn: 0.0710814	total: 2.94s	remaining: 1.24s
# 704:	learn: 0.0708802	total: 2.94s	remaining: 1.23s
# 705:	learn: 0.0708133	total: 2.95s	remaining: 1.23s
# 706:	learn: 0.0706475	total: 2.95s	remaining: 1.22s
# 707:	learn: 0.0705825	total: 2.96s	remaining: 1.22s
# 708:	learn: 0.0703954	total: 2.96s	remaining: 1.22s
# 709:	learn: 0.0702707	total: 2.97s	remaining: 1.21s
# 710:	learn: 0.0702195	total: 2.97s	remaining: 1.21s
# 711:	learn: 0.0701322	total: 2.98s	remaining: 1.2s
# 712:	learn: 0.0700403	total: 2.98s	remaining: 1.2s
# 713:	learn: 0.0698270	total: 2.98s	remaining: 1.2s
# 714:	learn: 0.0697250	total: 2.99s	remaining: 1.19s
# 715:	learn: 0.0696622	total: 2.99s	remaining: 1.19s
# 716:	learn: 0.0695270	total: 3s	remaining: 1.18s
# 717:	learn: 0.0694062	total: 3s	remaining: 1.18s
# 718:	learn: 0.0692868	total: 3.01s	remaining: 1.17s
# 719:	learn: 0.0691945	total: 3.01s	remaining: 1.17s
# 720:	learn: 0.0690944	total: 3.01s	remaining: 1.17s
# 721:	learn: 0.0689985	total: 3.02s	remaining: 1.16s
# 722:	learn: 0.0689287	total: 3.02s	remaining: 1.16s
# 723:	learn: 0.0688222	total: 3.02s	remaining: 1.15s
# 724:	learn: 0.0687789	total: 3.03s	remaining: 1.15s
# 725:	learn: 0.0686132	total: 3.03s	remaining: 1.14s
# 726:	learn: 0.0685253	total: 3.04s	remaining: 1.14s
# 727:	learn: 0.0684528	total: 3.04s	remaining: 1.14s
# 728:	learn: 0.0682149	total: 3.04s	remaining: 1.13s
# 729:	learn: 0.0681445	total: 3.05s	remaining: 1.13s
# 730:	learn: 0.0679511	total: 3.05s	remaining: 1.12s
# 731:	learn: 0.0677970	total: 3.06s	remaining: 1.12s
# 732:	learn: 0.0676937	total: 3.06s	remaining: 1.11s
# 733:	learn: 0.0676350	total: 3.06s	remaining: 1.11s
# 734:	learn: 0.0675124	total: 3.07s	remaining: 1.1s
# 735:	learn: 0.0673249	total: 3.07s	remaining: 1.1s
# 736:	learn: 0.0672417	total: 3.08s	remaining: 1.1s
# 737:	learn: 0.0671674	total: 3.08s	remaining: 1.09s
# 738:	learn: 0.0670742	total: 3.08s	remaining: 1.09s
# 739:	learn: 0.0670100	total: 3.09s	remaining: 1.08s
# 740:	learn: 0.0669787	total: 3.09s	remaining: 1.08s
# 741:	learn: 0.0668049	total: 3.1s	remaining: 1.08s
# 742:	learn: 0.0667071	total: 3.1s	remaining: 1.07s
# 743:	learn: 0.0665182	total: 3.11s	remaining: 1.07s
# 744:	learn: 0.0664191	total: 3.11s	remaining: 1.06s
# 745:	learn: 0.0662875	total: 3.12s	remaining: 1.06s
# 746:	learn: 0.0661297	total: 3.12s	remaining: 1.06s
# 747:	learn: 0.0661077	total: 3.13s	remaining: 1.05s
# 748:	learn: 0.0659343	total: 3.13s	remaining: 1.05s
# 749:	learn: 0.0659085	total: 3.13s	remaining: 1.04s
# 750:	learn: 0.0657461	total: 3.14s	remaining: 1.04s
# 751:	learn: 0.0656567	total: 3.14s	remaining: 1.03s
# 752:	learn: 0.0655476	total: 3.15s	remaining: 1.03s
# 753:	learn: 0.0654183	total: 3.15s	remaining: 1.03s
# 754:	learn: 0.0652565	total: 3.15s	remaining: 1.02s
# 755:	learn: 0.0650908	total: 3.16s	remaining: 1.02s
# 756:	learn: 0.0649502	total: 3.16s	remaining: 1.01s
# 757:	learn: 0.0648175	total: 3.17s	remaining: 1.01s
# 758:	learn: 0.0647988	total: 3.17s	remaining: 1.01s
# 759:	learn: 0.0647214	total: 3.18s	remaining: 1s
# 760:	learn: 0.0646208	total: 3.18s	remaining: 999ms
# 761:	learn: 0.0645036	total: 3.19s	remaining: 995ms
# 762:	learn: 0.0644247	total: 3.19s	remaining: 991ms
# 763:	learn: 0.0643716	total: 3.19s	remaining: 987ms
# 764:	learn: 0.0642797	total: 3.2s	remaining: 983ms
# 765:	learn: 0.0641719	total: 3.2s	remaining: 978ms
# 766:	learn: 0.0641433	total: 3.21s	remaining: 974ms
# 767:	learn: 0.0640120	total: 3.21s	remaining: 970ms
# 768:	learn: 0.0638939	total: 3.21s	remaining: 965ms
# 769:	learn: 0.0637927	total: 3.22s	remaining: 961ms
# 770:	learn: 0.0636977	total: 3.22s	remaining: 957ms
# 771:	learn: 0.0636534	total: 3.23s	remaining: 953ms
# 772:	learn: 0.0634965	total: 3.23s	remaining: 948ms
# 773:	learn: 0.0633721	total: 3.23s	remaining: 944ms
# 774:	learn: 0.0632680	total: 3.24s	remaining: 940ms
# 775:	learn: 0.0632374	total: 3.24s	remaining: 935ms
# 776:	learn: 0.0631420	total: 3.24s	remaining: 931ms
# 777:	learn: 0.0630200	total: 3.25s	remaining: 927ms
# 778:	learn: 0.0628521	total: 3.25s	remaining: 923ms
# 779:	learn: 0.0627415	total: 3.25s	remaining: 918ms
# 780:	learn: 0.0626566	total: 3.26s	remaining: 914ms
# 781:	learn: 0.0625886	total: 3.26s	remaining: 910ms
# 782:	learn: 0.0625256	total: 3.27s	remaining: 906ms
# 783:	learn: 0.0624450	total: 3.27s	remaining: 902ms
# 784:	learn: 0.0623325	total: 3.28s	remaining: 898ms
# 785:	learn: 0.0622033	total: 3.28s	remaining: 894ms
# 786:	learn: 0.0621233	total: 3.29s	remaining: 890ms
# 787:	learn: 0.0620594	total: 3.29s	remaining: 886ms
# 788:	learn: 0.0619204	total: 3.3s	remaining: 882ms
# 789:	learn: 0.0617600	total: 3.3s	remaining: 878ms
# 790:	learn: 0.0616670	total: 3.31s	remaining: 874ms
# 791:	learn: 0.0615975	total: 3.31s	remaining: 870ms
# 792:	learn: 0.0614888	total: 3.32s	remaining: 867ms
# 793:	learn: 0.0613742	total: 3.33s	remaining: 863ms
# 794:	learn: 0.0612700	total: 3.33s	remaining: 859ms
# 795:	learn: 0.0612153	total: 3.33s	remaining: 855ms
# 796:	learn: 0.0611350	total: 3.34s	remaining: 851ms
# 797:	learn: 0.0610382	total: 3.35s	remaining: 847ms
# 798:	learn: 0.0609958	total: 3.35s	remaining: 843ms
# 799:	learn: 0.0609200	total: 3.36s	remaining: 839ms
# 800:	learn: 0.0608234	total: 3.36s	remaining: 835ms
# 801:	learn: 0.0607359	total: 3.37s	remaining: 831ms
# 802:	learn: 0.0606094	total: 3.37s	remaining: 827ms
# 803:	learn: 0.0604466	total: 3.38s	remaining: 823ms
# 804:	learn: 0.0603735	total: 3.38s	remaining: 820ms
# 805:	learn: 0.0602779	total: 3.39s	remaining: 816ms
# 806:	learn: 0.0601566	total: 3.39s	remaining: 812ms
# 807:	learn: 0.0600896	total: 3.4s	remaining: 808ms
# 808:	learn: 0.0600135	total: 3.4s	remaining: 804ms
# 809:	learn: 0.0599131	total: 3.41s	remaining: 800ms
# 810:	learn: 0.0597526	total: 3.41s	remaining: 796ms
# 811:	learn: 0.0596498	total: 3.42s	remaining: 792ms
# 812:	learn: 0.0595638	total: 3.42s	remaining: 787ms
# 813:	learn: 0.0594617	total: 3.43s	remaining: 783ms
# 814:	learn: 0.0593886	total: 3.43s	remaining: 779ms
# 815:	learn: 0.0592396	total: 3.44s	remaining: 775ms
# 816:	learn: 0.0592066	total: 3.44s	remaining: 771ms
# 817:	learn: 0.0591508	total: 3.45s	remaining: 767ms
# 818:	learn: 0.0590195	total: 3.45s	remaining: 762ms
# 819:	learn: 0.0589034	total: 3.45s	remaining: 758ms
# 820:	learn: 0.0588823	total: 3.46s	remaining: 754ms
# 821:	learn: 0.0587759	total: 3.46s	remaining: 749ms
# 822:	learn: 0.0586288	total: 3.46s	remaining: 745ms
# 823:	learn: 0.0585517	total: 3.47s	remaining: 741ms
# 824:	learn: 0.0584571	total: 3.47s	remaining: 737ms
# 825:	learn: 0.0583817	total: 3.48s	remaining: 733ms
# 826:	learn: 0.0583271	total: 3.48s	remaining: 728ms
# 827:	learn: 0.0582808	total: 3.48s	remaining: 724ms
# 828:	learn: 0.0581817	total: 3.49s	remaining: 720ms
# 829:	learn: 0.0580312	total: 3.49s	remaining: 715ms
# 830:	learn: 0.0579770	total: 3.5s	remaining: 711ms
# 831:	learn: 0.0578676	total: 3.5s	remaining: 707ms
# 832:	learn: 0.0577384	total: 3.5s	remaining: 703ms
# 833:	learn: 0.0576418	total: 3.51s	remaining: 698ms
# 834:	learn: 0.0575623	total: 3.51s	remaining: 694ms
# 835:	learn: 0.0574634	total: 3.52s	remaining: 690ms
# 836:	learn: 0.0574309	total: 3.52s	remaining: 685ms
# 837:	learn: 0.0573769	total: 3.52s	remaining: 681ms
# 838:	learn: 0.0572796	total: 3.53s	remaining: 677ms
# 839:	learn: 0.0571689	total: 3.53s	remaining: 673ms
# 840:	learn: 0.0571127	total: 3.54s	remaining: 668ms
# 841:	learn: 0.0570136	total: 3.54s	remaining: 664ms
# 842:	learn: 0.0568780	total: 3.54s	remaining: 660ms
# 843:	learn: 0.0568421	total: 3.55s	remaining: 656ms
# 844:	learn: 0.0567258	total: 3.55s	remaining: 652ms
# 845:	learn: 0.0566449	total: 3.56s	remaining: 647ms
# 846:	learn: 0.0565244	total: 3.56s	remaining: 643ms
# 847:	learn: 0.0564228	total: 3.56s	remaining: 639ms
# 848:	learn: 0.0563012	total: 3.61s	remaining: 643ms
# 849:	learn: 0.0561555	total: 3.62s	remaining: 639ms
# 850:	learn: 0.0560779	total: 3.63s	remaining: 635ms
# 851:	learn: 0.0560111	total: 3.63s	remaining: 631ms
# 852:	learn: 0.0559003	total: 3.64s	remaining: 627ms
# 853:	learn: 0.0558431	total: 3.64s	remaining: 623ms
# 854:	learn: 0.0557858	total: 3.65s	remaining: 618ms
# 855:	learn: 0.0557361	total: 3.65s	remaining: 614ms
# 856:	learn: 0.0555721	total: 3.65s	remaining: 610ms
# 857:	learn: 0.0554891	total: 3.66s	remaining: 605ms
# 858:	learn: 0.0552802	total: 3.66s	remaining: 601ms
# 859:	learn: 0.0552000	total: 3.66s	remaining: 596ms
# 860:	learn: 0.0551285	total: 3.67s	remaining: 592ms
# 861:	learn: 0.0550183	total: 3.67s	remaining: 588ms
# 862:	learn: 0.0549702	total: 3.67s	remaining: 583ms
# 863:	learn: 0.0548758	total: 3.68s	remaining: 579ms
# 864:	learn: 0.0547866	total: 3.68s	remaining: 575ms
# 865:	learn: 0.0547331	total: 3.69s	remaining: 570ms
# 866:	learn: 0.0546399	total: 3.69s	remaining: 566ms
# 867:	learn: 0.0545589	total: 3.69s	remaining: 562ms
# 868:	learn: 0.0544644	total: 3.7s	remaining: 557ms
# 869:	learn: 0.0544298	total: 3.7s	remaining: 553ms
# 870:	learn: 0.0543458	total: 3.71s	remaining: 549ms
# 871:	learn: 0.0542868	total: 3.71s	remaining: 544ms
# 872:	learn: 0.0542404	total: 3.71s	remaining: 540ms
# 873:	learn: 0.0541519	total: 3.72s	remaining: 536ms
# 874:	learn: 0.0541090	total: 3.72s	remaining: 532ms
# 875:	learn: 0.0540359	total: 3.72s	remaining: 527ms
# 876:	learn: 0.0539839	total: 3.73s	remaining: 523ms
# 877:	learn: 0.0539051	total: 3.73s	remaining: 519ms
# 878:	learn: 0.0538764	total: 3.74s	remaining: 515ms
# 879:	learn: 0.0538456	total: 3.74s	remaining: 510ms
# 880:	learn: 0.0537566	total: 3.75s	remaining: 506ms
# 881:	learn: 0.0536531	total: 3.75s	remaining: 502ms
# 882:	learn: 0.0536223	total: 3.75s	remaining: 498ms
# 883:	learn: 0.0535611	total: 3.76s	remaining: 493ms
# 884:	learn: 0.0534249	total: 3.76s	remaining: 489ms
# 885:	learn: 0.0532917	total: 3.77s	remaining: 485ms
# 886:	learn: 0.0531572	total: 3.77s	remaining: 481ms
# 887:	learn: 0.0531211	total: 3.78s	remaining: 476ms
# 888:	learn: 0.0530626	total: 3.78s	remaining: 472ms
# 889:	learn: 0.0530042	total: 3.79s	remaining: 468ms
# 890:	learn: 0.0529448	total: 3.79s	remaining: 464ms
# 891:	learn: 0.0528121	total: 3.79s	remaining: 459ms
# 892:	learn: 0.0527643	total: 3.8s	remaining: 455ms
# 893:	learn: 0.0526449	total: 3.8s	remaining: 451ms
# 894:	learn: 0.0526206	total: 3.81s	remaining: 446ms
# 895:	learn: 0.0525630	total: 3.81s	remaining: 442ms
# 896:	learn: 0.0524704	total: 3.81s	remaining: 438ms
# 897:	learn: 0.0523705	total: 3.82s	remaining: 433ms
# 898:	learn: 0.0522793	total: 3.82s	remaining: 429ms
# 899:	learn: 0.0522433	total: 3.82s	remaining: 425ms
# 900:	learn: 0.0522073	total: 3.83s	remaining: 420ms
# 901:	learn: 0.0521407	total: 3.83s	remaining: 416ms
# 902:	learn: 0.0520456	total: 3.83s	remaining: 412ms
# 903:	learn: 0.0519450	total: 3.84s	remaining: 408ms
# 904:	learn: 0.0518851	total: 3.84s	remaining: 403ms
# 905:	learn: 0.0518288	total: 3.85s	remaining: 399ms
# 906:	learn: 0.0517084	total: 3.85s	remaining: 395ms
# 907:	learn: 0.0516254	total: 3.85s	remaining: 390ms
# 908:	learn: 0.0515401	total: 3.86s	remaining: 386ms
# 909:	learn: 0.0514232	total: 3.86s	remaining: 382ms
# 910:	learn: 0.0513188	total: 3.86s	remaining: 377ms
# 911:	learn: 0.0512514	total: 3.87s	remaining: 373ms
# 912:	learn: 0.0511512	total: 3.87s	remaining: 369ms
# 913:	learn: 0.0510662	total: 3.87s	remaining: 365ms
# 914:	learn: 0.0509652	total: 3.88s	remaining: 360ms
# 915:	learn: 0.0509057	total: 3.88s	remaining: 356ms
# 916:	learn: 0.0508523	total: 3.88s	remaining: 352ms
# 917:	learn: 0.0508264	total: 3.89s	remaining: 347ms
# 918:	learn: 0.0507796	total: 3.89s	remaining: 343ms
# 919:	learn: 0.0506954	total: 3.9s	remaining: 339ms
# 920:	learn: 0.0506150	total: 3.9s	remaining: 335ms
# 921:	learn: 0.0505486	total: 3.9s	remaining: 330ms
# 922:	learn: 0.0504486	total: 3.91s	remaining: 326ms
# 923:	learn: 0.0503805	total: 3.91s	remaining: 322ms
# 924:	learn: 0.0503438	total: 3.92s	remaining: 317ms
# 925:	learn: 0.0502086	total: 3.92s	remaining: 313ms
# 926:	learn: 0.0500694	total: 3.92s	remaining: 309ms
# 927:	learn: 0.0500118	total: 3.93s	remaining: 305ms
# 928:	learn: 0.0499398	total: 3.93s	remaining: 300ms
# 929:	learn: 0.0498291	total: 3.94s	remaining: 296ms
# 930:	learn: 0.0496808	total: 3.94s	remaining: 292ms
# 931:	learn: 0.0496141	total: 3.94s	remaining: 288ms
# 932:	learn: 0.0495630	total: 3.95s	remaining: 284ms
# 933:	learn: 0.0495371	total: 3.95s	remaining: 279ms
# 934:	learn: 0.0494248	total: 3.96s	remaining: 275ms
# 935:	learn: 0.0493910	total: 3.96s	remaining: 271ms
# 936:	learn: 0.0493311	total: 3.96s	remaining: 267ms
# 937:	learn: 0.0492593	total: 3.97s	remaining: 262ms
# 938:	learn: 0.0491417	total: 3.97s	remaining: 258ms
# 939:	learn: 0.0490463	total: 3.98s	remaining: 254ms
# 940:	learn: 0.0489699	total: 3.98s	remaining: 250ms
# 941:	learn: 0.0489318	total: 3.98s	remaining: 245ms
# 942:	learn: 0.0488641	total: 3.99s	remaining: 241ms
# 943:	learn: 0.0488263	total: 3.99s	remaining: 237ms
# 944:	learn: 0.0487898	total: 4s	remaining: 233ms
# 945:	learn: 0.0487298	total: 4s	remaining: 228ms
# 946:	learn: 0.0486080	total: 4s	remaining: 224ms
# 947:	learn: 0.0485190	total: 4.01s	remaining: 220ms
# 948:	learn: 0.0484161	total: 4.01s	remaining: 216ms
# 949:	learn: 0.0483675	total: 4.01s	remaining: 211ms
# 950:	learn: 0.0482825	total: 4.02s	remaining: 207ms
# 951:	learn: 0.0482320	total: 4.02s	remaining: 203ms
# 952:	learn: 0.0481656	total: 4.03s	remaining: 199ms
# 953:	learn: 0.0480825	total: 4.03s	remaining: 194ms
# 954:	learn: 0.0479977	total: 4.03s	remaining: 190ms
# 955:	learn: 0.0479515	total: 4.04s	remaining: 186ms
# 956:	learn: 0.0479063	total: 4.04s	remaining: 182ms
# 957:	learn: 0.0478072	total: 4.04s	remaining: 177ms
# 958:	learn: 0.0477221	total: 4.05s	remaining: 173ms
# 959:	learn: 0.0476852	total: 4.05s	remaining: 169ms
# 960:	learn: 0.0476398	total: 4.05s	remaining: 165ms
# 961:	learn: 0.0475968	total: 4.06s	remaining: 160ms
# 962:	learn: 0.0475090	total: 4.06s	remaining: 156ms
# 963:	learn: 0.0474314	total: 4.07s	remaining: 152ms
# 964:	learn: 0.0473394	total: 4.07s	remaining: 148ms
# 965:	learn: 0.0472947	total: 4.07s	remaining: 143ms
# 966:	learn: 0.0472498	total: 4.08s	remaining: 139ms
# 967:	learn: 0.0471921	total: 4.08s	remaining: 135ms
# 968:	learn: 0.0471247	total: 4.08s	remaining: 131ms
# 969:	learn: 0.0470849	total: 4.09s	remaining: 126ms
# 970:	learn: 0.0470543	total: 4.09s	remaining: 122ms
# 971:	learn: 0.0469265	total: 4.09s	remaining: 118ms
# 972:	learn: 0.0468789	total: 4.1s	remaining: 114ms
# 973:	learn: 0.0468013	total: 4.1s	remaining: 110ms
# 974:	learn: 0.0467143	total: 4.11s	remaining: 105ms
# 975:	learn: 0.0466136	total: 4.11s	remaining: 101ms
# 976:	learn: 0.0464601	total: 4.12s	remaining: 96.9ms
# 977:	learn: 0.0463687	total: 4.12s	remaining: 92.7ms
# 978:	learn: 0.0462823	total: 4.12s	remaining: 88.4ms
# 979:	learn: 0.0461779	total: 4.13s	remaining: 84.2ms
# 980:	learn: 0.0461124	total: 4.13s	remaining: 80ms
# 981:	learn: 0.0459834	total: 4.13s	remaining: 75.8ms
# 982:	learn: 0.0458918	total: 4.14s	remaining: 71.6ms
# 983:	learn: 0.0457621	total: 4.14s	remaining: 67.4ms
# 984:	learn: 0.0456803	total: 4.15s	remaining: 63.2ms
# 985:	learn: 0.0455627	total: 4.15s	remaining: 59ms
# 986:	learn: 0.0455033	total: 4.16s	remaining: 54.8ms
# 987:	learn: 0.0454095	total: 4.16s	remaining: 50.6ms
# 988:	learn: 0.0453201	total: 4.17s	remaining: 46.3ms
# 989:	learn: 0.0452518	total: 4.17s	remaining: 42.1ms
# 990:	learn: 0.0451749	total: 4.18s	remaining: 37.9ms
# 991:	learn: 0.0451071	total: 4.18s	remaining: 33.7ms
# 992:	learn: 0.0450610	total: 4.18s	remaining: 29.5ms
# 993:	learn: 0.0449850	total: 4.19s	remaining: 25.3ms
# 994:	learn: 0.0449473	total: 4.19s	remaining: 21.1ms
# 995:	learn: 0.0449072	total: 4.2s	remaining: 16.9ms
# 996:	learn: 0.0448618	total: 4.2s	remaining: 12.6ms
# 997:	learn: 0.0448084	total: 4.21s	remaining: 8.43ms
# 998:	learn: 0.0447701	total: 4.21s	remaining: 4.21ms
# 999:	learn: 0.0446850	total: 4.21s	remaining: 0us
# CatBoost Classifier
# Model performance for Training set
# - Accuracy: 1.0000
# - Precision: 1.0000
# - Recall: 1.0000
# - F1 Score: 1.0000
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.8419
# - Precision: 0.7899
# - Recall: 0.8419
# - F1 Score: 0.8125
# ===================================
#
#
# XGBoost Classifier
# Model performance for Training set
# - Accuracy: 1.0000
# - Precision: 1.0000
# - Recall: 1.0000
# - F1 Score: 1.0000
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.8309
# - Precision: 0.7811
# - Recall: 0.8309
# - F1 Score: 0.8028
# ===================================

# %%
results = pd.DataFrame(list(zip(model_list, accuracy_list, _accuracy_train)), 
                       columns=['Model Name', 'Accuracy Test', 'Accuracy Train']).sort_values(by=["Accuracy Test"],
                                                                       ascending=False)
results
# Out:
#                Model Name  Accuracy Test  Accuracy Train
# 2  Support Vector Machine       0.863971        0.844526
# 5       Gradient Boosting       0.863971        0.964121
# 1           Random Forest       0.852941        1.000000
# 7   Multilayer Perceptron       0.845588        0.871205
# 8     CatBoost Classifier       0.841912        1.000000
# 4     Logistic Regression       0.838235        0.836247
# 9      XGBoost Classifier       0.830882        1.000000
# 3     K-Nearest Neighbors       0.819853        0.863845
# 6    Gaussian Naive Bayes       0.797794        0.762649
# 0           Decision Tree       0.757353        1.000000

# %% [markdown]
# ## Top 3 Models:
#
# 1. **Support Vector Machine (SVM):**
#    - **Accuracy:** Test (0.864) & Train (0.845) are reasonably close, indicating good generalization (less overfitting).
#    - **Interpretability:** SVMs are well-established and interpretable, making them a good choice for industries where explainability is often valuable.
#    - **Reasoning:** SVMs exhibit good generalization with a balanced trade-off between train and test accuracy, making them reliable for real-world applications.
#
# 2. **Gradient Boosting:**
#    - **Accuracy:** Test (0.864) is similar to SVM, suggesting decent generalization.
#    - **Train accuracy:** (0.964) is higher than test accuracy, but not excessively high, indicating a moderate risk of overfitting.
#    - **Interpretability:** Gradient Boosting models can achieve high accuracy while offering some interpretability, which is beneficial for understanding model predictions in industry settings.
#    - **Reasoning:** Despite the slight risk of overfitting, Gradient Boosting offers competitive accuracy and interpretability, making it suitable for a wide range of industrial applications.
#
# 3. **Logistic Regression:**
#    - **Accuracy:** Test (0.838) is lower than SVM and Gradient Boosting, but it might be sufficient depending on the industry's specific requirements.
#    - **Generalization:** Train and Test accuracy are relatively close (0.838 vs 0.836) suggesting good generalization and less overfitting.
#    - **Interpretability:** Logistic Regression is highly interpretable, making it ideal for understanding the model's decision-making process, which is crucial in many industries.
#    - **Reasoning:** Despite slightly lower accuracy, Logistic Regression offers excellent interpretability and generalization, making it a reliable choice for industries where transparency and model understanding are paramount.
#
# ## Why not Random Forest, CatBoost, or XGBoost:
#
# - While Random Forest, CatBoost, and XGBoost achieve high training accuracy (1.000), their test accuracy is lower than SVM and Gradient Boosting, indicating a high risk of overfitting.
# - These models might perform well on the training data but might not generalize well to unseen data, leading to poor real-world performance.
#
# ## Factors to Consider:
#
# - **Generalization vs. Overfitting:** Models with a significant gap between training and test accuracy may suffer from overfitting, impacting their performance on new data.
# - **Interpretability:** For industries requiring model transparency, interpretability is crucial. SVM, Logistic Regression, and Gradient Boosting offer varying degrees of interpretability.
# - **Industry Requirements:** The acceptable accuracy threshold and the importance of interpretability can vary based on the specific industry and application.
# - **Computational Efficiency:** Consider the training and prediction time of different models, especially for large datasets or real-time predictions. Logistic Regression and SVM are generally faster to train and use compared to complex ensemble methods.
#
# ## Conclusion:
#
# - The top three models, SVM, Logistic Regression, and Gradient Boosting, offer a balance between accuracy, interpretability, and generalization, making them suitable for various industrial applications.
# - Selecting the best model involves a trade-off between accuracy, interpretability, computational efficiency, and industry-specific requirements, ensuring alignment with the organization's goals and constraints.
#
# ## Additional Tips:
#
# - Consider techniques like cross-validation to get a more robust estimate of model performance.
# - Ensemble methods combining SVM, Logistic Regression, and Gradient Boosting can further enhance predictive performance and model robustness.

# %% [markdown]
# #### Hyper parameter tuning.

# %%
from sklearn.model_selection import RandomizedSearchCV

# Define a smaller hyperparameter grid with focus on commonly used values
param_grid_svc = {
    'kernel': ['linear', 'rbf'],  # Start with common choices
    'C': [0.01, 0.1, 1, 10],
    'gamma': ['scale', 'auto', 0.1],  # Focus on relevant gamma values
    'class_weight': [None, 'balanced']
}

# Use RandomizedSearchCV for efficient search
svm_cv = RandomizedSearchCV(SVC(), param_grid_svc, cv=5, scoring='accuracy')  # Set cv for cross-validation

# Fit the model with hyperparameter tuning
svm_cv.fit(X_train, y_train)

# Access the best model with tuned hyperparameters
best_svm = svm_cv.best_estimator_
print("Best Hyperparameters:", best_svm)
# Out:
# Best Hyperparameters: SVC(C=0.01, kernel='linear')

# %%
# Calculate accuracy for train and test datasets
train_accuracy = best_svm.score(X_train, y_train)
test_accuracy = best_svm.score(X_test, y_test)

print("Train Accuracy:", train_accuracy)
print("Test Accuracy:", test_accuracy)
# Out:
# Train Accuracy: 0.8178472861085556
# Test Accuracy: 0.8198529411764706

# %%
# Define a larger hyperparameter grid with more options
param_grid_svc = {
    'kernel': ['linear', 'poly', 'rbf'],#, 'sigmoid'],
    'C': [1, 10, 100],
    'gamma': ['scale', 'auto', 0.01, 0.1, 1],
    'class_weight': [None, 'balanced']
}

# Increase the number of iterations for RandomizedSearchCV
svm_cv = RandomizedSearchCV(SVC(), param_grid_svc, cv=5, scoring='accuracy', n_iter=200)

# Fit the model with hyperparameter tuning
svm_cv.fit(X_train, y_train)

# Access the best model with tuned hyperparameters
best_svm = svm_cv.best_estimator_
print("Best Hyperparameters:", best_svm)

# Calculate accuracy for train and test datasets
train_accuracy = best_svm.score(X_train, y_train)
test_accuracy = best_svm.score(X_test, y_test)

print("Train Accuracy:", train_accuracy)
print("Test Accuracy:", test_accuracy)
# Out:
# C:\Users\mayuo\anaconda3\envs\machineLearning\lib\site-packages\sklearn\model_selection\_search.py:307: UserWarning: The total space of parameters 90 is smaller than n_iter=200. Running 90 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# Best Hyperparameters: SVC(C=1, gamma=1)
# Train Accuracy: 0.9586016559337627
# Test Accuracy: 0.8455882352941176

# %%
param_grid_gbr = {
  'learning_rate': [0.05, 0.1, 0.2],
  'n_estimators': [100, 150, 200],
  'max_depth': [3, 5, 8],
  'min_samples_split': [2, 5],
  'min_samples_leaf': [1, 3],
}

# Use RandomizedSearchCV with early stopping
gbr_cv = RandomizedSearchCV(GradientBoostingClassifier(), param_grid_gbr, cv=5, scoring="accuracy")

# Fit the model with hyperparameter tuning
gbr_cv.fit(X_train, y_train)

# Access the best model with tuned hyperparameters
best_gbr = gbr_cv.best_estimator_

train_accuracy = best_gbr.score(X_train, y_train)
test_accuracy = best_gbr.score(X_test, y_test)

print("Train Accuracy:", train_accuracy)
print("Test Accuracy:", test_accuracy)
# Out:
# Train Accuracy: 1.0
# Test Accuracy: 0.8272058823529411

# %%
best_gbr, best_svm
# Out:
# (GradientBoostingClassifier(max_depth=5, min_samples_leaf=3, min_samples_split=5,
#                             n_estimators=200),
#  SVC(C=1, gamma=1))

# %%
# Define the logistic regression classifier
logistic_regression = LogisticRegression()

# Define the hyperparameters grid
param_grid_lr = {
  'C': [0.01, 0.1, 1, 10, 100, 1000],  # Regularization parameter
  'solver': ['lbfgs', 'liblinear', 'sag', 'newton-cg'],  # Optimization algorithms
  'penalty': ['l2', 'l1'],  # Penalty types (L1 or L2 regularization)
  'class_weight': [None, 'balanced', 'balanced_subsample'],  # Class weighting strategies
  'max_iter': [100, 200, 500]  # Maximum iterations for training
}

# Perform Grid Search Cross Validation
grid_search = GridSearchCV(estimator=logistic_regression, param_grid=param_grid_lr, cv=5, scoring='accuracy')
grid_search.fit(X_train, y_train)

# Get the best parameters
best_params = grid_search.best_params_
print("Best Hyperparameters:", best_params)

# Instantiate a logistic regression model with the best hyperparameters
best_logistic_regression = LogisticRegression(**best_params)

# Fit the model on the training data
best_logistic_regression.fit(X_train, y_train)

# Evaluate the model on the test data
test_accuracy = best_logistic_regression.score(X_test, y_test)
print("Test Accuracy:", test_accuracy)
# Out:
# Best Hyperparameters: {'C': 1, 'class_weight': None, 'max_iter': 100, 'penalty': 'l1', 'solver': 'liblinear'}
# Test Accuracy: 0.8382352941176471

# %%
best_logistic_regression
# Out:
# LogisticRegression(C=1, penalty='l1', solver='liblinear')

# %%
import warnings
warnings.filterwarnings("ignore")

# Define the hyperparameter grid
param_grid_lr = {
  'C': [0.001, 0.01, 0.1, 1, 10, 100],  # Regularization parameter
  'solver': ['lbfgs', 'liblinear', 'sag'],  # Optimization algorithms
  'class_weight': [None, 'balanced']  # Handle imbalanced classes (optional)
}

# Define RandomizedSearchCV with Logistic Regression
lr_cv = RandomizedSearchCV(LogisticRegression(), param_grid_lr, cv=5, scoring='accuracy', n_iter=100)

# Fit the model with hyperparameter tuning
lr_cv.fit(X_train, y_train)

# Access the best model with tuned hyperparameters
best_lr = lr_cv.best_estimator_
print("Best Hyperparameters:", best_lr)

# Calculate accuracy on train and test sets
train_accuracy = best_lr.score(X_train, y_train)
test_accuracy = best_lr.score(X_test, y_test)

print("Train Accuracy:", train_accuracy)
print("Test Accuracy:", test_accuracy)
# Out:
# Best Hyperparameters: LogisticRegression(C=1, solver='liblinear')
# Train Accuracy: 0.8334866605335787
# Test Accuracy: 0.8419117647058824

# %%
lg = LogisticRegression()

# %%
lg.get_params()
# Out:
# {'C': 1.0,
#  'class_weight': None,
#  'dual': False,
#  'fit_intercept': True,
#  'intercept_scaling': 1,
#  'l1_ratio': None,
#  'max_iter': 100,
#  'multi_class': 'auto',
#  'n_jobs': None,
#  'penalty': 'l2',
#  'random_state': None,
#  'solver': 'lbfgs',
#  'tol': 0.0001,
#  'verbose': 0,
#  'warm_start': False}
